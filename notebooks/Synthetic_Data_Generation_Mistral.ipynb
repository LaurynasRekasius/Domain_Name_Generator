# %% [markdown]
# <a href="https://colab.research.google.com/github/LaurynasRekasius/Domain_Name_Generator/blob/main/notebooks/Synthetic_Data_Generation_Mistral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objective:
# - Generate synthetic data for fine-tuning
# - Dataset should have two components:
#   - Business description
#   - List of suggested domain names for corresponding description
#     - Names should be in JSON format, to get the best results from fine-tuning

# %% [markdown]
# Note:
# - I decided to use Mistral model due to their license. It allows generated data to be used for other model training. Which is not always the case.
# - Due to low costs and faster inference times I am using here Mistal AI API
# - I picked Mistral 7b over Mixtral 8x7B for main dataset generation due to better price/performance ratio for this particular task

# %% [markdown]
# #####################
#
# This notebooks runs on CPU

# %% [markdown]
# # Setup Libraries

# %%
# !pip install mistralai -qU

from IPython.display import clear_output
import re
import json
import random

clear_output()

# %%
from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

api_key = "i7o7t7R1BTF1U7BChdi7eSjY9SgevD3x"
model = "open-mixtral-8x7b" #open-mistral-7b #open-mixtral-8x7b

client = MistralClient(api_key=api_key)

# %% [markdown]
# # Generating list of diverse business

# %% [markdown]
# First step is to generate a list of business industries. This will make easier to generate more diverse business description that would not repeat that much.

# %%
messages = [
    ChatMessage(role="user",
                content="""
Generate a diverse and unique list of business industries starting from the most popular ones. The list should have 200 items.
"""
    )
          ]

chat_response = client.chat(
    model=model,
    messages=messages,
    temperature = 0.7
)

industries_string = chat_response.choices[0].message.content
print(industries_string)
# Out:
# 1. Technology/Software
# 2. Financial Services
# 3. Healthcare
# 4. Retail
# 5. Professional Services (e.g. law, consulting)
# 6. Manufacturing
# 7. Construction
# 8. Education
# 9. Real Estate
# 10. Wholesale Trade
# 11. Arts, Entertainment, and Recreation
# 12. Accommodation and Food Services
# 13. Transportation and Warehousing
# 14. Information Services
# 15. Administrative and Support Services
# 16. Mining, Quarrying, and Oil and Gas Extraction
# 17. Utilities
# 18. Agriculture, Forestry, Fishing and Hunting
# 19. Management of Companies and Enterprises
# 20. Scientific Research and Development Services
# 21. Repair and Maintenance
# 22. Waste Management and Remediation Services
# 23. Personal and Laundry Services
# 24. Religious, Grantmaking, Civic, Professional and Similar Organizations
# 25. Social Assistance
# 26. Telecommunications
# 27. Insurance Carriers
# 28. Publishing Industries (except Internet)
# 29. Broadcasting (except Internet)
# 30. Motion Picture and Sound Recording Industries
# 31. Broadcasting and Telecommunications
# 32. Data Processing, Hosting, and Related Services
# 33. Other Information Services
# 34. Other Professional, Scientific, and Technical Services
# 35. Rental and Leasing Services
# 36. Merchant Wholesalers, Durable Goods
# 37. Merchant Wholesalers, Nondurable Goods
# 38. Clothing and Clothing Accessories Stores
# 39. Shoe Stores
# 40. Furniture and Home Furnishings Stores
# 41. Electronics and Appliance Stores
# 42. Building Material and Garden Equipment and Supplies Dealers
# 43. Food and Beverage Stores
# 44. General Merchandise Stores
# 45. Department Stores
# 46. Sporting Goods, Hobby, Book and Music Stores
# 47. Health and Personal Care Stores
# 48. Used Merchandise Stores
# 49. Direct Selling Establishments
# 50. Gasoline Stations
# 51. Automobile Dealers
# 52. Automotive Equipment Rental and Leasing
# 53. Automotive Repair and Maintenance
# 54. Transportation Equipment Manufacturing
# 55. Motor Vehicle and Parts Dealers
# 56. Rail Transportation
# 57. Transit and Ground Passenger Transportation
# 58. Scenic and Sightseeing Transportation
# 59. Support Activities for Transportation
# 60. Warehousing and Storage
# 61. Publishing Industries (except Internet)
# 62. Newspaper, Periodical, Book, and Directory Publishers
# 63. Software Publishers
# 64. Motion Picture and Video Industries
# 65. Sound Recording Industries
# 66. Radio and Television Broadcasting
# 67. Cable and Other Subscription Programming
# 68. Internet Service Providers, Web Search Portals, and Data Processing Services
# 69. Internet Publishing and Broadcasting and Web Search Portals
# 70. Data Processing, Hosting, and Related Services
# 71. Other Information Services
# 72. Computer Systems Design and Related Services
# 73. Custom Computer Programming Services
# 74. Computer Facilities Management Services
# 75. Other Computer Related Services
# 76. Architectural, Engineering, and Related Services
# 77. Landscape Architectural Services
# 78. Engineering Services
# 79. Survey and Mapping (except Geophysical) Services
# 80. Specialized Design Services
# 81. Management, Scientific, and Technical Consulting Services
# 82. Scientific Research and Development Services
# 83. Environmental Consulting Services
# 84. Advertising, Public Relations, and Related Services
# 85. Advertising Agencies
# 86. Public Relations Agencies
# 87. Media Buying Agencies
# 88. Outdoor Advertising
# 89. Exhibition Services
# 90. Publishing Industries (except Internet)
# 91. Greeting Card Publisher
# 92. Musical Instrument and Supplies Manufacturing
# 93. Jewelry Manufacturing
# 94. Sporting and Athletic Goods Manufacturing
# 95. Apparel Knitting Mills
# 96. Textile Mills
# 97. Textile Product Mills
# 98. Leather and Allied Product Manufacturing
# 99. Wood Product Manufacturing
# 100. Nonmetallic Mineral Product Manufacturing
# 101. Primary Metal Manufacturing
# 102. Fabricated Metal Product Manufacturing
# 103. Machinery Manufacturing
# 104. Computer and Electronic Product Manufacturing
# 105. Electrical Equipment, Appliance, and Component Manufacturing
# 106. Transportation Equipment Manufacturing
# 107. Furniture and Related Product Manufacturing
# 108. Miscellaneous Manufacturing
# 109. Logging
# 110. Oil and Gas Extraction
# 111. Mining (except Oil and Gas)
# 112. Support Activities for Mining
# 113. Utilities
# 114. Electric Power Generation, Transmission and Distribution
# 115. Natural Gas Distribution
# 116. Water, Sewage, and Other Systems
# 117. Construction
# 118. Building Construction
# 119. Heavy and Civil Engineering Construction
# 120. Specialty Trade Contractors
# 121. Foundation, Structure, and Building Exterior Contractors
# 122. Building Equipment Contractors
# 123. Building Finishing Contractors
# 124. Other Specialty Trade Contractors
# 125. Educational Services
# 126. Colleges, Universities, and Professional Schools
# 127. Junior Colleges
# 128. Vocational Schools
# 129. Business Schools and Computer and Management Training
# 130. Technical and Trade Schools
# 131. Educational Support Services
# 132. Health Care and Social Assistance
# 133. Ambulatory Health Care Services
# 134. Offices of Physicians
# 135. Home Health Care Services
# 136. Nursing Care Facilities (Skilled Nursing Facilities)
# 137. Community Care for the Elderly
# 138. Community Food and Housing, and Emergency and Other Relief Services
# 139. Individual and Family Services
# 140. Social Assistance
# 141. Child Day Care Services
# 142. Vocational Rehabilitation Services
# 143. Services for the Elderly and Disabled
# 144. Arts, Entertainment, and Recreation
# 145. Performing Arts Companies
# 146. Spectator Sports
# 147. Promoters of Performing Arts, Sports, and Similar Events
# 148. Agents and Managers for Artists, Athletes, Entertainers, and Other Public Figures
# 149. Independent Artists, Writers, and Performers
# 150. Museums, Historical Sites, and Similar Institutions
# 151. Accommodation
# 152. Traveler Accommodation
# 153. Food Services and Drinking Places
# 154. Full-Service Restaurants
# 155. Limited-Service Eating Places
# 156. Special Food Services
# 157. Other Food Services
# 158. Drinking Places (Alcoholic Beverages)
# 159. Repair and Maintenance
# 160. Automotive Repair and Maintenance
# 161. Electronic and Precision Equipment Repair and Maintenance
# 162. Commercial and Industrial Machinery and Equipment (except Automotive and Electronic) Repair and Maintenance
# 163. Personal and Household Goods Repair and Maintenance
# 164. Waste Management and Remediation Services
# 165. Waste Collection
# 166. Waste Treatment and Disposal
# 167. Remediation Services
# 168. Other Waste Management Services
# 169. Professional, Scientific, and Technical Services
# 170. Legal Services
# 171. Accounting, Tax Preparation, Bookkeeping, and Payroll Services
# 172. Architectural, Engineering, and Related Services
# 173. Specialized Design Services
# 174. Management, Scientific, and Technical Consulting Services
# 175. Scientific Research and Development Services
# 176. Advertising, Public Relations, and Related Services
# 177. Market Research and Public Opinion Polling
# 178. Photographic Services
# 179. Translation and Interpretation Services
# 180. Administrative and Support Services
# 181. Employment Services
# 182. Travel Arrangement and Reservation Services
# 183. Security Services for Insurance Carriers
# 184. Services to Buildings and Dwellings
# 185. Janitorial Services
# 186. Landscaping Services
# 187. Packaging and Labeling Services
# 188. Pet Care (except Veterinary) Services
# 189. Investigation Services
# 190. Other Support Services
# 191. Merchant Wholesalers, Durable Goods
# 192. Merchant Wholesalers, Nondurable Goods
# 193. Wholesale Trade Agents and Brokers
# 194. Miscellaneous Durable Goods Merchant Wholesalers
# 195. Miscellaneous Nondurable Goods Merchant Wholesalers
# 196. Nondurable Goods (except Groceries) Wholesalers
# 197. Grocery Wholesalers
# 198. Apparel, Piece Goods, and Notions Merchant Wholesalers
# 199. Furniture and Home Furnishings Merchant Wholesalers
# 200. Machinery, Equipment, and Supplies Merchant Wholesalers.

# %% [markdown]
# Format the output as a list for easier usage

# %%
# Regular expression to match the pattern
pattern = r'\d+\.\s*(.*)'

# Find all matches of the pattern in the string, excluding the numbers
industries_list = re.findall(pattern, industries_string)

# Remove dublicated industries
industries = list(set(industries_list))

print(len(industries))
# Out:
# 179

# %% [markdown]
# # Create Initial Sample of Business Descriptions

# %% [markdown]
# These descriptions will bring more variety to the prompts making sure we get more relevant and diverse business descriptions in the final dataset.

# %% [markdown]
# Following code use Mistral 7B only

# %%
model = "open-mistral-7b"  # Model selection
num_queries = 3  # Number of times to run query for each industry

# Initialize the Mistral client
client = MistralClient(api_key=api_key)

# %%
# Initialize storage for results
all_results = []
all_raw = []

# Base prompt template with placeholder for industries
base_prompt_template = """
Generate a single detailed and creative business description for a company in the {industry} industry, followed by five unique website name suggestions. The names should be relevant to the business description and business name if provided, focusing on the core services or products offered. The names should not include domain extensions like .com or prefixes like www. Ensure each business name is a single word or a creative combination of words that could potentially be used as a domain name. Provide the business description and the five suggested names in a JSON format.

Here is a response format example:
{{
    "description": "An innovative forestry company offering tree planting services, reforestation projects, and sustainable wood products.",
    "names": [
        "forestfuel",
        "treeteam",
        "ecogrowth",
        "woodwise",
        "greengrowth"
    ]
}}
"""

# %%
# Iterate through each industry
for industry in industries:
    print(industry)  # For debugging

    for _ in range(num_queries):  # Run queries X time per industry
        # Update prompt with correct industry
        content = base_prompt_template.format(industry=industry)
        #print(content)  # For debugging
        messages = [ChatMessage(role="user", content=content)]

        chat_response = client.chat(model=model,
                                    messages=messages,
                                    max_tokens=200,
                                    temperature=0.3)

        # Store the raw chat response content
        response_content = chat_response.choices[0].message.content if chat_response.choices else "No response"
        print(response_content)

        # Attempt to process and parse the response
        try:
            response_dict = json.loads(response_content)
            json_status = "YES"
            response_dict['industry'] = industry  # Add the industry to the result
        except (json.JSONDecodeError, ValueError) as e:
            json_status = "NO"
            response_dict = {"error": f"Failed to process response: {e}", "industry": industry}

        result_record = {
            "response": response_dict,
            "JSON": json_status,
        }

        # Add the results to lists
        all_results.append(result_record)
        all_raw.append(chat_response)

# Filter only valid JSON responses
sample_results = [result for result in all_results if result['JSON'] == "YES"]
# Out:
# Streaming output truncated to the last 5000 lines.
#         "mindfulfaith",
#         "serenitystream"
#     ],
#     "industry": "Religious Organizations"
# }
# {
#     "description": "A spiritual sanctuary providing inspirational sermons, community outreach programs, and personalized counseling services to foster emotional and spiritual growth.",
#     "names": [
#         "soulseed",
#         "sparkfaith",
#         "heartwisdom",
#         "mindfulspark",
#         "peacebloom"
#     ],
#     "industry": "Religious Organizations"
# }
# {
#     "description": "A spiritual sanctuary providing inspirational sermons, community outreach programs, and personalized counseling services to foster emotional and spiritual growth.",
#     "names": [
#         "soulseed",
#         "sparkfaith",
#         "heartwisdom",
#         "mindfulspirit",
#         "serenitystream"
#     ],
#     "industry": "Religious Organizations"
# }
# Grantmaking and Giving Services
# {
#     "description": "Empathy Grants: A compassionate grantmaking organization providing financial assistance and resources to underfunded community projects and individuals in need, focusing on mental health, education, and environmental sustainability.",
#     "names": [
#         "CompassionGrant",
#         "EmpowerGive",
#         "HeartFunding",
#         "GentleGrants",
#         "CaringCircles"
#     ],
#     "industry": "Grantmaking and Giving Services"
# }
# {
#     "description": "Empathy Foundation: A leading grantmaking organization dedicated to uplifting communities by providing financial resources, strategic partnerships, and capacity-building services to nonprofits and social enterprises.",
#     "names": [
#         "GrantEmpower",
#         "CommunityCapital",
#         "EmpowerGive",
#         "SocialSustain",
#         "PhilanthroLink"
#     ],
#     "industry": "Grantmaking and Giving Services"
# }
# {
#     "description": "Empathy Grants: A compassionate grantmaking organization providing financial assistance to individuals and communities in need, focusing on mental health and well-being.",
#     "names": [
#         "HealingHands",
#         "MindfulGiving",
#         "CompassionFund",
#         "WellspringGrants",
#         "GentleGifts"
#     ],
#     "industry": "Grantmaking and Giving Services"
# }
# Civic and Social Organizations
# {
#     "description": "Empowering Communities: A dynamic organization dedicated to fostering social development, volunteer engagement, and advocacy programs.",
#     "names": [
#         "CommunitySpark",
#         "VolunteerVibes",
#         "SocialSynergy",
#         "AdvocacyApex",
#         "ImpactIgnite"
#     ],
#     "industry": "Civic and Social Organizations"
# }
# {
#     "description": "Empowering Communities: A dynamic organization dedicated to fostering social development, volunteering opportunities, and advocacy initiatives.",
#     "names": [
#         "CommunitySpark",
#         "VolunteerVibes",
#         "SocialSynergy",
#         "AdvocacyApex",
#         "ImpactIgnite"
#     ],
#     "industry": "Civic and Social Organizations"
# }
# {
#     "description": "Empowering Communities: A dynamic organization dedicated to fostering social development, volunteering opportunities, and advocacy initiatives.",
#     "names": [
#         "CommunitySpark",
#         "Volunetwork",
#         "SocialBoost",
#         "AdvocacyHub",
#         "EmpowerLink"
#     ],
#     "industry": "Civic and Social Organizations"
# }
# Business, Professional, Labor, Political, and Similar Organizations
# {
#     "description": "A trailblazing think tank dedicated to advocating for workers' rights, providing professional development training, and bridging the gap between labor and politics.",
#     "names": [
#         "WorkRise",
#         "LaborLink",
#         "AdvocacyApex",
#         "EmpowerEmploy",
#         "PolicyPeak"
#     ],
#     "industry": "Business, Professional, Labor, Political, and Similar Organizations"
# }
# {
#     "description": "A trailblazing think tank dedicated to advocating for workers' rights, providing expert labor consulting services, and fostering political dialogue to shape future policies.",
#     "names": [
#         "WorkRise",
#         "LaborLeap",
#         "PolicyPulse",
#         "AdvocacyArch",
#         "EmpowerEcho"
#     ],
#     "industry": "Business, Professional, Labor, Political, and Similar Organizations"
# }
# {
#     "description": "A trailblazing think tank dedicated to advocating for workers' rights, providing professional development training, and fostering political alliances. Our mission is to empower the labor force with the skills and resources needed to succeed in today's dynamic economy.",
#     "names": [
#         "WorkforceWise",
#         "EmpowerAlliance",
#         "SkillBuilders",
#         "AdvocacyArchitects",
#         "LaborLuminary"
#     ],
#     "industry": "Business, Professional, Labor, Political, and Similar Organizations"
# }
# Museums, Historical Sites, and Similar Institutions
# {
#     "description": "Timeless Treasures: A captivating museum and cultural center, showcasing local history through immersive exhibits, educational programs, and interactive experiences.",
#     "names": [
#         "HeritageHaven",
#         "StoryKeep",
#         "MemoryMaze",
#         "PastPursuits",
#         "HistoryHub"
#     ],
#     "industry": "Museums, Historical Sites, and Similar Institutions"
# }
# {
#     "description": "Timeless Treasures: A captivating museum that brings history to life through immersive exhibits, educational programs, and authentic artifacts preservation.",
#     "names": [
#         "HeritageHub",
#         "TimeCapsule",
#         "StoryKeep",
#         "PastPassion",
#         "RelicRevive"
#     ],
#     "industry": "Museums, Historical Sites, and Similar Institutions"
# }
# {
#     "description": "Time Traveler's Nexus: A captivating museum and research institute, merging history and technology to transport visitors through immersive exhibits and interactive experiences, unearthing the stories of the past and bridging the gap between generations.",
#     "names": [
#         "ChronoHub",
#         "HistoricaLab",
#         "TimeTrail",
#         "HeritageTech",
#         "EpochPortal"
#     ],
#     "industry": "Museums, Historical Sites, and Similar Institutions"
# }
# Spectator Sports
# {
#     "description": "Sports Spectacle: A pioneering company specializing in the production and management of large-scale spectator sports events, delivering unforgettable experiences through state-of-the-art infrastructure, top-tier athlete management, and fan engagement strategies.",
#     "names": [
#         "SportsSpectrum",
#         "ThrillDome",
#         "GameGrid",
#         "ArenaApex",
#         "EventElevate"
#     ],
#     "industry": "Spectator Sports"
# }
# {
#     "description": "ThrillSpectators: A pioneering company specializing in immersive fan experiences, virtual and augmented reality technologies, and innovative merchandise for spectator sports.",
#     "names": [
#         "RealitySports",
#         "FanExperience",
#         "SpectraTech",
#         "VirtualTeam",
#         "AugmentedArena"
#     ],
#     "industry": "Spectator Sports"
# }
# {
#     "description": "SportsPulse: A dynamic sports analytics company providing real-time player performance data, predictive injury analysis, and personalized training programs for professional athletes and sports teams.",
#     "names": [
#         "statspulse",
#         "athletesync",
#         "performanceplus",
#         "insightathlete",
#         "predictperf"
#     ],
#     "industry": "Spectator Sports"
# }
# Promoters of Performing Arts, Sports, and Similar Events
# {
#     "description": "A dynamic enterprise specializing in producing and promoting awe-inspiring artistic and athletic events, offering ticket sales, merchandise, and exclusive experiences.",
#     "names": [
#         "ArtSprint",
#         "EventEuphoria",
#         "PerformPassion",
#         "SpectacleSphere",
#         "ThrillTicket"
#     ],
#     "industry": "Promoters of Performing Arts, Sports, and Similar Events"
# }
#
# For a business named "Artistic Events Unlimited":
#
# {
#     "description": "A creative powerhouse producing and promoting a diverse range of artistic and athletic events, offering ticket sales, merchandise, and exclusive experiences.",
#     "names": [
#         "ArtEventHub",
#         "CreativeCatalyst",
#         "EntertainEvolve",
#         "Un
# {
#     "description": "A dynamic enterprise specializing in producing and promoting awe-inspiring artistic and athletic events, offering ticket sales, merchandise, and exclusive experiences.",
#     "names": [
#         "ArtSportHub",
#         "EventEuphoria",
#         "CreativeLeap",
#         "EntertainSphere",
#         "PerformPassion"
#     ],
#     "industry": "Promoters of Performing Arts, Sports, and Similar Events"
# }
# {
#     "description": "A dynamic enterprise specializing in producing and promoting awe-inspiring artistic and athletic events, offering ticketing services, talent management, and event production.",
#     "names": [
#         "ArtSportHub",
#         "EventEcho",
#         "CreativeSpectacle",
#         "EntertainSphere",
#         "StagePassion"
#     ],
#     "industry": "Promoters of Performing Arts, Sports, and Similar Events"
# }
# Independent Artists, Writers, and Performers
# {
#     "description": "A vibrant collective of independent artists, writers, and performers, providing customized creative solutions for clients. Our team of innovative talents specializes in visual art, literature, music, and theatrical performances, tailoring each project to meet unique client needs and preferences.",
#     "names": [
#         "ArtisansAlley",
#         "CreativeCraze",
#         "InkwellIndependents",
#         "MuseMakers",
#         "TalentTrove"
#     ],
#     "industry": "Independent Artists, Writers, and Performers"
# }
# {
#     "description": "MuseMingle: A vibrant marketplace connecting patrons with independent artists, writers, and performers, offering custom commissions, workshops, and collaborative projects.",
#     "names": [
#         "ArtisanAlliance",
#         "CreativeCrossover",
#         "PatronPassion",
#         "InspireIntersect",
#         "MuseMingleMarket"
#     ],
#     "industry": "Independent Artists, Writers, and Performers"
# }
# {
#     "description": "Inspire Arts, a vibrant collective of independent artists, writers, and performers, providing customized creative solutions for events, media, and personal projects. Our team of passionate and skilled individuals specializes in original artwork, captivating literature, and enthralling performances tailored to your unique vision.",
#     "names": [
#         "MuseMingle",
#         "ArtisanAssemble",
#         "CreativeCraze",
#         "InspireInk",
#         "TalentTrove"
#     ],
#     "industry": "Independent Artists, Writers, and Performers"
# }
# Agents and Managers for Artists, Athletes, Entertainers, and Other Public Figures
# {
#     "description": "A trailblazing talent agency representing artists, athletes, entertainers, and public figures, providing strategic planning, brand development, and contract negotiation services.",
#     "names": [
#         "StarStride",
#         "TalentThrive",
#         "FameFusion",
#         "CelebCraft",
#         "RiseRep"
#     ],
#     "industry": "Agents and Managers for Artists, Athletes, Entertainers, and Other Public Figures"
# }
# {
#     "description": "A distinguished talent agency representing a diverse roster of artists, athletes, entertainers, and public figures, providing strategic planning, brand development, and career advancement services.",
#     "names": [
#         "StarStride",
#         "FameForge",
#         "TalentThrive",
#         "IconicLeap",
#         "BrightSpark"
#     ],
#     "industry": "Agents and Managers for Artists, Athletes, Entertainers, and Other Public Figures"
# }
# {
#     "description": "A trailblazing talent agency representing artists, athletes, entertainers, and public figures, providing strategic planning, brand development, and contract negotiations.",
#     "names": [
#         "StarStride",
#         "TalentThrive",
#         "FameForge",
#         "IconicInk",
#         "BoldBrush"
#     ],
#     "industry": "Agents and Managers for Artists, Athletes, Entertainers, and Other Public Figures"
# }
# Miscellaneous Professional and Technical Services
# {
#     "description": "Introducing TechSolutions: a pioneering firm specializing in advanced data analytics, AI integration, and cybersecurity consulting services. Our team of experts collaborates with businesses to optimize operations, enhance security, and unlock hidden insights. With a customer-centric approach, we tailor our solutions to meet unique industry needs.",
#     "names": [
#         "AnalytiQ",
#         "DataGuard",
#         "InnovAIte",
#         "CyberShield",
#         "IntellectInsight"
#     ],
#     "industry": "Miscellaneous Professional and Technical Services"
# }
# {
#     "description": "Introducing NeuroTech Innovations, a pioneering company specializing in advanced neural network solutions, AI integration, and data analytics for businesses. Our team of experts collaborates with clients to optimize operations, enhance decision-making processes, and unlock new opportunities through cutting-edge technology.",
#     "names": [
#         "synapsehub",
#         "neuraledge",
#         "brainwaveAI",
#         "intellicog",
#         "neuronetix"
#     ],
#     "industry": "Miscellaneous Professional and Technical Services"
# }
# {
#     "description": "Introducing TechSolutions: a pioneering firm specializing in artificial intelligence consulting, data analytics, and automation engineering. Our team of experts collaborates with businesses to optimize operations, enhance decision-making processes, and create innovative solutions tailored to unique industry needs.",
#     "names": [
#         "AIBoost",
#         "DataDrive",
#         "AutomatePro",
#         "IntellectFlow",
#         "SolutionSynergy"
#     ],
#     "industry": "Miscellaneous Professional and Technical Services"
# }
# Religious (except Schools) and Welfare Activities
# {
#     "description": "SacredSerenity: A compassionate organization providing spiritual counseling, community outreach programs, and crisis intervention services.",
#     "names": [
#         "SoulSolace",
#         "HeartHaven",
#         "DivineComfort",
#         "SpiritSanctuary",
#         "FaithFoster"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# {
#     "description": "SacredSolace: A compassionate organization providing spiritual counseling, community outreach programs, and crisis intervention services.",
#     "names": [
#         "SolaceSpark",
#         "HealingHaven",
#         "DivineDwelling",
#         "FaithfulFellowship",
#         "InspireIntervention"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# {
#     "description": "A compassionate organization providing spiritual guidance, community outreach programs, and crisis intervention services.",
#     "names": [
#         "soulshelter",
#         "heavenlyhaven",
#         "spiritspace",
#         "angelicassist",
#         "divineconnect"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# Gambling Industries
# {
#     "description": "Lucky Stars Casino: A dazzling online gaming platform where fortune favors the bold. Offering an extensive collection of games, from classic table games to thrilling slots, all dealt by our state-of-the-art AI dealers. Our secure and user-friendly platform guarantees an unforgettable gaming experience. Join us today and let the stars align in your favor!",
#     "names": [
#         "StellarCasino",
#         "LuckyGalaxy",
#         "CosmicGames",
#         "StarSpins",
#         "GalacticJackpots"
#     ],
#     "industry": "Gambling Industries"
# }
# {
#     "description": "Lucky Stars Casino: A dazzling online gambling destination offering a vast selection of games, from classic slots to live dealer tables, with a commitment to responsible gaming and top-tier security.",
#     "names": [
#         "StellarBet",
#         "LuckyRoll",
#         "GalacticGames",
#         "CasinoSparks",
#         "StarWinnings"
#     ],
#     "industry": "Gambling Industries"
# }
# {
#     "description": "Lucky Stars Casino: A dazzling virtual gaming paradise, where fortune favors the bold. Offering an extensive collection of online slots, table games, live dealer experiences, and daily promotions to bring excitement and potential winnings to every player.",
#     "names": [
#         "StellarCasino",
#         "FortuneSpin",
#         "LuckyGamesHub",
#         "CasinoGalaxy",
#         "RollTheDiceClub"
#     ],
#     "industry": "Gambling Industries"
# }
# Data Processing, Hosting, and Related Services
# {
#     "description": "Introducing DataVault, a trailblazing tech company specializing in secure data processing, advanced hosting solutions, and AI-driven data analytics. Our state-of-the-art facilities ensure top-notch data security and uninterrupted access to your valuable information. With our cutting-edge technologies and dedicated team of experts, we help businesses make informed decisions and optimize their operations.",
#     "names": [
#         "DataGuard",
#         "InfoShield",
#         "AnalytiQ",
#         "IntelStore",
#         "BrainBase"
#     ],
#     "industry": "Data Processing, Hosting, and Related Services"
# }
# {
#     "description": "Introducing DataVault, a trailblazing company in the Data Processing, Hosting, and Related Services industry. We provide secure, efficient, and scalable solutions for businesses looking to store, manage, and analyze their data. Our state-of-the-art data centers are equipped with advanced security measures and high-performance servers to ensure optimal data processing and hosting. Additionally, our team of data experts offers customized data analytics services to help businesses gain valuable insights from their data. With DataVault, businesses can focus on their core competencies while we take care of their data needs.",
#     "names": [
#         "Databoost",
#         "DataGuardian",
#         "InfoShield",
#         "DataSphere",
#         "IntelStore"
#     ],
#     "industry": "Data Processing, Hosting, and Related Services"
# }
# {
#     "description": "DataVault: A cutting-edge data processing and hosting company, providing secure, scalable, and customizable solutions for businesses and individuals. Our services include data analytics, machine learning, cloud storage, and IT infrastructure management.",
#     "names": [
#         "DataSanctuary",
#         "InfoGuardian",
#         "CloudCustodian",
#         "IntellectInsight",
#         "DataDynamo"
#     ],
#     "industry": "Data Processing, Hosting, and Related Services"
# }
# Other Information Services
# {
#     "description": "Intellisight: A pioneering data analytics company specializing in artificial intelligence and machine learning solutions for the legal industry. We provide predictive insights for case outcomes, contract analysis, and document review, revolutionizing the way law firms operate.",
#     "names": [
#         "lawinsight",
#         "predictlaw",
#         "justicedata",
#         "contractai",
#         "casediscover"
#     ],
#     "industry": "Other Information Services"
# }
# {
#     "description": "Intellisight: A pioneering data analytics firm specializing in artificial intelligence and machine learning solutions for the real estate industry. Our team of experts transforms raw property data into actionable insights, empowering clients to make informed decisions with confidence.",
#     "names": [
#         "datarealm",
#         "intelliproperty",
#         "analyticsedge",
#         "propertyinsight",
#         "wisdombase"
#     ],
#     "industry": "Other Information Services"
# }
# {
#     "description": "Intellisight: A pioneering data analytics firm specializing in artificial intelligence, machine learning, and predictive modeling to revolutionize the real estate industry by providing accurate property valuations, market insights, and personalized recommendations.",
#     "names": [
#         "propertyinsight",
#         "valuemodel",
#         "intellirealty",
#         "predictiveedge",
#         "datarealm"
#     ],
#     "industry": "Other Information Services"
# }
# Other Personal Services
# {
#     "description": "A pioneering memory enhancement studio providing personalized memory coaching, mnemonic techniques training, and memory assessment services.",
#     "names": [
#         "memorymaze",
#         "brainboost",
#         "mindmapper",
#         "memorymentor",
#         "memorymatrix"
#     ],
#     "industry": "Other Personal Services"
# }
# {
#     "description": "A pioneering memory enhancement studio, specializing in personalized memory coaching, memory improvement workshops, and custom memory aids.",
#     "names": [
#         "memorybloom",
#         "mindgarden",
#         "recallrevive",
#         "brainblossom",
#         "mentalbloom"
#     ],
#     "industry": "Other Personal Services"
# }
# {
#     "description": "Introducing 'Mindful Mending', a unique personal services company specializing in art therapy, mental health counseling, and custom-made clothing repairs. Our team of compassionate therapists and skilled tailors work together to help clients heal emotionally while restoring their cherished clothing items. By combining the power of creative expression and practical mending, Mindful Mending fosters self-care, self-esteem, and sustainable living.",
#     "names": [
#         "healthread",
#         "mendart",
#         "stitchtherapy",
#         "repairrejuvenate",
#         "createmend"
#     ],
#     "industry": "Other Personal Services"
# }
# Personal and Household Goods Repair and Maintenance
# {
#     "description": "SparkFix: Your go-to solution for swift and efficient repair and maintenance of all your personal and household appliances. Our team of expert technicians is dedicated to extending the life of your beloved items, ensuring your home runs smoothly and sustainably. From leaky faucets to faulty refrigerators, we've got you covered.",
#     "names": [
#         "FixNation",
#         "ApplianceAlive",
#         "HomeHeart",
#         "EcoMend",
#         "LifeLineAppliance"
#     ],
#     "industry": "Personal and Household Goods Repair and Maintenance"
# }
# {
#     "description": "SparkFix: Your go-to solution for reviving and maintaining personal appliances and household gadgets, specializing in prompt on-site repairs and eco-friendly parts replacement.",
#     "names": [
#         "ApplianceAwake",
#         "FixNSpark",
#         "EcoRepairPro",
#         "HomeGlow",
#         "ReviveSpark"
#     ],
#     "industry": "Personal and Household Goods Repair and Maintenance"
# }
# {
#     "description": "Revive Home: Your go-to destination for expert appliance repair, furniture restoration, and DIY home improvement solutions. Our team of skilled technicians and artisans breathe new life into your cherished possessions, ensuring they function at their best and maintain their timeless beauty.",
#     "names": [
#         "FixNRestore",
#         "ApplianceArtisans",
#         "HomeRevive",
#         "RestoreCrafters",
#         "DIYEssentials"
#     ],
#     "industry": "Personal and Household Goods Repair and Maintenance"
# }
# Personal Care Services
# {
#     "description": "Blissful Blooms is a personal care services company specializing in customized aromatherapy sessions, soothing massage therapies, and revitalizing facials using all-natural and ethically-sourced botanical ingredients. Our team of certified therapists tailors each session to meet the unique needs of every client, ensuring a relaxing and rejuvenating experience.",
#     "names": [
#         "AromaSanctuary",
#         "BotanicalBliss",
#         "NatureNurture",
#         "HerbalHaven",
#         "EssenceEscape"
#     ],
#     "industry": "Personal Care Services"
# }
# {
#     "description": "Luminous Blooms, a personal care services company dedicated to revitalizing minds and bodies through customized spa treatments, aromatherapy sessions, and holistic wellness consultations.",
#     "names": [
#         "AromaRevive",
#         "BlissSanctuary",
#         "SereneEssence",
#         "LuminaSpa",
#         "RadiantNest"
#     ],
#     "industry": "Personal Care Services"
# }
# {
#     "description": "Blissful Blooms, a personal care services company specializing in customized aromatherapy sessions, soothing massage therapies, and revitalizing facials using all-natural, ethically-sourced ingredients.",
#     "names": [
#         "AromaSanctuary",
#         "NaturalNurture",
#         "BlissfulEssences",
#         "PureRelaxation",
#         "EcoSpa"
#     ],
#     "industry": "Personal Care Services"
# }
# Death Care Services
# {
#     "description": "Eternal Embrace: A compassionate death care services company, providing personalized funeral arrangements, cremation services, and grief counseling.",
#     "names": [
#         "SerenityCare",
#         "EternalComfort",
#         "GentlePassages",
#         "MemorialMakers",
#         "HonorKeepers"
#     ],
#     "industry": "Death Care Services"
# }
# {
#     "description": "Eternal Embrace: A compassionate and innovative death care services company providing personalized funeral solutions, memorialization options, and grief counseling.",
#     "names": [
#         "memorialmuse",
#         "everlastingcomfort",
#         "serenitykeep",
#         "griefgarden",
#         "solacekeep"
#     ],
#     "industry": "Death Care Services"
# }
# {
#     "description": "Eternal Embrace: A compassionate death care services company providing personalized funeral solutions, memorialization options, and grief counseling.",
#     "names": [
#         "MementoMori",
#         "EternalSerenity",
#         "MemorialMakers",
#         "GriefGuardians",
#         "EternityEssence"
#     ],
#     "industry": "Death Care Services"
# }
# Social Advocacy Organizations
# {
#     "description": "Empower Voices, a social advocacy organization dedicated to amplifying underrepresented communities, providing education and resources, and fostering meaningful connections through collaborative initiatives.",
#     "names": [
#         "VoiceAmplifier",
#         "CommunityConnect",
#         "EmpowerLink",
#         "AdvocacyAlliance",
#         "UnityVoice"
#     ],
#     "industry": "Social Advocacy Organizations"
# }
# {
#     "description": "Empower Voices, a social advocacy organization dedicated to amplifying underrepresented communities through grassroots campaigns, educational programs, and policy advocacy.",
#     "names": [
#         "VoiceAmplify",
#         "CommunityEcho",
#         "EmpowerSpeak",
#         "UnheardVoices",
#         "AdvocacyEcho"
#     ],
#     "industry": "Social Advocacy Organizations"
# }
# {
#     "description": "Empowering Voices United (EVU) is a social advocacy organization dedicated to amplifying underrepresented communities and driving systemic change through grassroots campaigns, educational programs, and collaborative partnerships.",
#     "names": [
#         "AmplifyChange",
#         "VoiceUnite",
#         "EmpowerShift",
#         "CommunityEcho",
#         "ChangeAmplifier"
#     ],
#     "industry": "Social Advocacy Organizations"
# }
# Cemeteries and Crematories
# {
#     "description": "Eternal Rest Haven: A serene and tranquil final resting place, offering traditional cemetery services, modern crematories, and memorialization solutions, all infused with a touch of nature and personalized care.",
#     "names": [
#         "EternalNest",
#         "SereneRest",
#         "NatureMemento",
#         "MemorialGarden",
#         "EverlastingHaven"
#     ],
#     "industry": "Cemeteries and Crematories"
# }
# {
#     "description": "Eternal Rest: A tranquil and reverent cemetery and crematorium company, providing final resting places and personalized memorial services, ensuring a peaceful and comforting experience for families and loved ones.",
#     "names": [
#         "EternalPeace",
#         "SereneMemories",
#         "RestfulHaven",
#         "GentleFarewells",
#         "EverlastingComfort"
#     ],
#     "industry": "Cemeteries and Crematories"
# }
# {
#     "description": "Eternal Rest Haven: A serene and tranquil final resting place, offering traditional cemetery services, modern crematories, and memorialization solutions, all while maintaining a beautiful and peaceful environment for visitors.",
#     "names": [
#         "EternalSerenity",
#         "RestfulMemories",
#         "CemeterySolace",
#         "MemorialMeadows",
#         "EverlastingPeace"
#     ],
#     "industry": "Cemeteries and Crematories"
# }
# Wired Telecommunications Carriers
# {
#     "description": "Introducing PulseConnect, a trailblazing wired telecommunications carrier company delivering lightning-fast internet connectivity, unified communication solutions, and cutting-edge network security. Our advanced fiber-optic network ensures seamless communication for businesses and individuals, enabling them to stay connected and productive in today's digital world.",
#     "names": [
#         "FiberFlux",
#         "ConnectPulse",
#         "OptiLink",
#         "SpeedNexus",
#         "CommuniCore"
#     ],
#     "industry": "Wired Telecommunications Carriers"
# }
# {
#     "description": "Revolutionary wired telecommunications carrier delivering lightning-fast internet connections, unlimited data plans, and cutting-edge technological solutions for businesses and individuals.",
#     "names": [
#         "speedlink",
#         "techpulse",
#         "connectivityhub",
#         "datasprint",
#         "innovatewire"
#     ],
#     "industry": "Wired Telecommunications Carriers"
# }
# {
#     "description": "Revolutionary wired telecommunications carrier delivering lightning-fast internet connections, unlimited data plans, and cutting-edge network security solutions.",
#     "names": [
#         "hyperconnect",
#         "speedlink",
#         "securenet",
#         "infinitespeed",
#         "cyberguardian"
#     ],
#     "industry": "Wired Telecommunications Carriers"
# }
# Wireless Telecommunications Carriers (except Satellite)
# {
#     "description": "Revolutionary wireless telecommunications carrier delivering lightning-fast 5G connectivity, unlimited data plans, and exceptional customer service through a network of local stores and online support.",
#     "names": [
#         "speedwave",
#         "connectpulse",
#         "networkglow",
#         "pulsarphone",
#         "communitysignals"
#     ],
#     "industry": "Wireless Telecommunications Carriers (except Satellite)"
# }
# {
#     "description": "Revolutionary wireless telecommunications carrier delivering lightning-fast 5G connectivity, unlimited data plans, and exceptional customer service.",
#     "names": [
#         "speedwave",
#         "connectpulse",
#         "datasurge",
#         "networkglow",
#         "pulsepoint"
#     ],
#     "industry": "Wireless Telecommunications Carriers (except Satellite)"
# }
# {
#     "description": "Revolutionary wireless telecommunications carrier delivering lightning-fast 5G connectivity, unlimited data plans, and exceptional customer service.",
#     "names": [
#         "speedwave",
#         "connectpulse",
#         "datasurge",
#         "signalboost",
#         "premiumlink"
#     ],
#     "industry": "Wireless Telecommunications Carriers (except Satellite)"
# }
# Satellite Telecommunications
# {
#     "description": "SkyLink Communications: Pioneering satellite telecommunications with high-speed internet solutions, voice services, and data connectivity for remote areas and global enterprises.",
#     "names": [
#         "SatelliteSynergy",
#         "SpaceLinkHQ",
#         "GlobalGrid",
#         "SkyConnectivity",
#         "OrbitCommunications"
#     ],
#     "industry": "Satellite Telecommunications"
# }
# {
#     "description": "SkyConnect: A pioneering satellite telecommunications company providing global connectivity solutions, high-definition satellite TV, and data services for businesses and individuals in remote areas.",
#     "names": [
#         "SkyLink",
#         "SatelliteSynergy",
#         "GlobalGrid",
#         "SatelliteSpectrum",
#         "ConnectSat"
#     ],
#     "industry": "Satellite Telecommunications"
# }
# {
#     "description": "SkyLink Communications: Pioneering satellite telecommunications, we connect the world's most remote regions with reliable, high-speed internet and voice solutions. Our cutting-edge technology enables businesses and communities in far-flung areas to thrive, fostering economic growth and social development.",
#     "names": [
#         "SatelliteSynergy",
#         "GlobalGrid",
#         "RemoteConnect",
#         "SkySignal",
#         "SpaceLinkHub"
#     ],
#     "industry": "Satellite Telecommunications"
# }
# Sound Recording Industries
# {
#     "description": "Sonic Harmony: A pioneering sound recording studio specializing in music production, voice-over recording, and sound design for films and advertisements, utilizing state-of-the-art equipment and industry-leading engineers.",
#     "names": [
#         "soundwave",
#         "harmonyhub",
#         "musemedia",
#         "sonicspark",
#         "voicevibes"
#     ],
#     "industry": "Sound Recording Industries"
# }
# {
#     "description": "Sonic Harmony: A pioneering sound recording studio specializing in music production, sound design, and podcasting, utilizing state-of-the-art equipment and experienced engineers to bring creative visions to life.",
#     "names": [
#         "soundscape",
#         "harmonyhub",
#         "audiogenius",
#         "sonicforge",
#         "melodymint"
#     ],
#     "industry": "Sound Recording Industries"
# }
# {
#     "description": "SonicSphere: A pioneering sound recording studio providing top-tier music production services, immersive 3D audio experiences, and custom sound design for film, games, and virtual reality.",
#     "names": [
#         "soundscapes",
#         "audiogenesis",
#         "sonicforge",
#         "soundalchemy",
#         "audioworks"
#     ],
#     "industry": "Sound Recording Industries"
# }
# Radio and Television Broadcasting
# {
#     "description": "Spectrum Soundwave: A pioneering media company specializing in radio and television production, offering customized content creation, advertising solutions, and audience engagement services.",
#     "names": [
#         "wavecast",
#         "soundbite",
#         "spectrumsync",
#         "mediawave",
#         "broadcastbeam"
#     ],
#     "industry": "Radio and Television Broadcasting"
# }
# {
#     "description": "Spectrum Soundwave: A pioneering media company specializing in radio and television production, offering custom content creation, advertising solutions, and audience engagement strategies.",
#     "names": [
#         "soundbite",
#         "spectrumwave",
#         "mediacraft",
#         "broadcastboost",
#         "adwave"
#     ],
#     "industry": "Radio and Television Broadcasting"
# }
# {
#     "description": "Spectrum Soundwaves: A pioneering media company specializing in radio and television production, offering custom content creation, advertising solutions, and audience engagement strategies.",
#     "names": [
#         "soundbite",
#         "spectrumwaves",
#         "mediacrest",
#         "broadcastboom",
#         "creativepulse"
#     ],
#     "industry": "Radio and Television Broadcasting"
# }
# Software Publishers
# {
#     "description": "Introducing SoftSolution, a trailblazing software publishing company specializing in customizable business applications, AI-driven automation tools, and user-friendly interfaces to streamline operations and boost productivity for businesses of all sizes.",
#     "names": [
#         "SoftBoost",
#         "AppSynergy",
#         "IntelliFlow",
#         "BusinessBloom",
#         "AutomatePro"
#     ],
#     "industry": "Software Publishers"
# }
# {
#     "description": "Introducing 'CodeGenius', a trailblazing software publishers company specializing in custom software development, AI integration, and user-friendly app design for businesses of all sizes.",
#     "names": [
#         "CodeSynergy",
#         "AppInnovators",
#         "IntelliDesign",
#         "BrainWaveTech",
#         "LogicMasters"
#     ],
#     "industry": "Software Publishers"
# }
# {
#     "description": "Intelligent Software Solutions: A trailblazing company specializing in custom software development, AI integration, and cybersecurity consulting services for businesses of all sizes.",
#     "names": [
#         "CodeIntellect",
#         "BrainWareSolutions",
#         "IntelliLogic",
#         "ProtectiveMind",
#         "SynapseSolutions"
#     ],
#     "industry": "Software Publishers"
# }
# Computer Systems Design and Related Services
# {
#     "description": "TechVenture: A pioneering computer systems design company specializing in custom software development, IT consulting, and cybersecurity solutions, empowering businesses to thrive in the digital age.",
#     "names": [
#         "techventure",
#         "codepioneer",
#         "digitalempower",
#         "cyberguardian",
#         "sysnova"
#     ],
#     "industry": "Computer Systems Design and Related Services"
# }
# {
#     "description": "InnovateTech: A pioneering computer systems design firm specializing in custom software development, cybersecurity solutions, and IT consulting services, leveraging cutting-edge technology to empower businesses and enhance productivity.",
#     "names": [
#         "techpioneer",
#         "innovatecode",
#         "cybersecureit",
#         "productivityplus",
#         "techboost"
#     ],
#     "industry": "Computer Systems Design and Related Services"
# }
# {
#     "description": "TechVision: A pioneering computer systems design company specializing in custom software development, IT consulting, and cybersecurity solutions, empowering businesses to thrive in the digital age.",
#     "names": [
#         "techshield",
#         "codepioneer",
#         "innovatech",
#         "cyberguard",
#         "solutionforge"
#     ],
#     "industry": "Computer Systems Design and Related Services"
# }
# Computer and Peripheral Equipment Manufacturing
# {
#     "description": "TechNexus: Pioneering the future with cutting-edge computer hardware and peripheral solutions, engineered for peak performance and sleek design.",
#     "names": [
#         "PeripheralPulse",
#         "TechBoost",
#         "HardwareHarmony",
#         "InnovateInput",
#         "SynapseSolutions"
#     ],
#     "industry": "Computer and Peripheral Equipment Manufacturing"
# }
# {
#     "description": "TechNexus: Pioneering the future with cutting-edge computer hardware and peripherals, engineered for peak performance and sleek design. Our custom-built systems cater to gamers, professionals, and businesses, ensuring unparalleled speed, reliability, and style.",
#     "names": [
#         "PerformancePeak",
#         "SleekSynergy",
#         "TechTranscend",
#         "InnovationNexus",
#         "SpeedSculpt"
#     ],
#     "industry": "Computer and Peripheral Equipment Manufacturing"
# }
# {
#     "description": "TechVenture: Pioneering the future with cutting-edge computer hardware and peripheral solutions, specializing in custom-built gaming PCs, high-performance workstations, and ergonomic accessories.",
#     "names": [
#         "TechPioneer",
#         "PeripheralPro",
#         "HardwareHaven",
#         "GameBoost",
#         "ErgonomicEdge"
#     ],
#     "industry": "Computer and Peripheral Equipment Manufacturing"
# }
# Computer and Peripheral Equipment and Software Merchant Wholesalers
# {
#     "description": "TechSynergy: A trailblazing company in the Computer and Peripheral Equipment and Software Merchant Wholesalers industry, specializing in providing cutting-edge technology solutions for businesses. Our extensive offerings include top-tier hardware, advanced software, and customizable IT consulting services. With a commitment to staying ahead of the curve, we ensure our clients have access to the latest technology to streamline their operations and boost productivity.",
#     "names": [
#         "SynergyTech",
#         "TechBoost",
#         "InnovateSphere",
#         "TechFusion",
#         "SolutionNexus"
#     ],
#     "industry": "Computer and Peripheral Equipment and Software Merchant Wholesalers"
# }
# {
#     "description": "TechSynergy: A trailblazing company in the Computer and Peripheral Equipment and Software Merchant Wholesalers industry, specializing in cutting-edge technology solutions for businesses. We offer a wide range of products from top manufacturers, custom software development, and IT consulting services to help businesses streamline their operations and enhance productivity.",
#     "names": [
#         "SynergyTech",
#         "TechBoost",
#         "InnovateSphere",
#         "SolutionNexus",
#         "TechFusion"
#     ],
#     "industry": "Computer and Peripheral Equipment and Software Merchant Wholesalers"
# }
# {
#     "description": "TechSynergy: A pioneering merchant wholesaler specializing in advanced computer hardware, cutting-edge peripherals, and custom software solutions. Our team of experts curates and distributes top-tier technology products to businesses and educational institutions, ensuring optimal performance and productivity.",
#     "names": [
#         "SynergyTech",
#         "HardwareHub",
#         "TechNexus",
#         "PeripheralPro",
#         "SoftwareSynergy"
#     ],
#     "industry": "Computer and Peripheral Equipment and Software Merchant Wholesalers"
# }
# Computer and Electronic Product Manufacturing
# {
#     "description": "RevTech Innovations: Pioneering the future with cutting-edge computer components and custom-built gaming systems. Our team of experts meticulously designs and assembles each part, ensuring optimal performance and unparalleled user experience. From high-speed processors to vibrant graphics cards, every component is rigorously tested for quality and compatibility. Our commitment to innovation and customer satisfaction sets us apart in the competitive tech market.",
#     "names": [
#         "techforge",
#         "componentcraft",
#         "performancepeak",
#         "gaminggrind",
#         "innovatechbuild"
#     ],
#     "industry": "Computer and Electronic Product Manufacturing"
# }
# {
#     "description": "TechGenius: A pioneering computer and electronic product manufacturing company specializing in the design, development, and production of advanced, eco-friendly technology solutions. Our cutting-edge products include energy-efficient laptops, solar-powered smartphones, and biodegradable computer components. Our commitment to sustainability and innovation sets us apart in the industry.",
#     "names": [
#         "EcoTech",
#         "GreenCircuits",
#         "SolarSynth",
#         "EcoGadgets",
#         "BioBytes"
#     ],
#     "industry": "Computer and Electronic Product Manufacturing"
# }
# {
#     "description": "TechGenius: A cutting-edge company specializing in custom-built gaming computers, high-performance workstations, and virtual reality solutions. Our team of experts designs and assembles each system to meet the unique needs of our clients, ensuring top-tier performance and unparalleled user experience.",
#     "names": [
#         "VirtualVortex",
#         "PerformancePioneer",
#         "GamingGuru",
#         "TechTailor",
#         "RealityForge"
#     ],
#     "industry": "Computer and Electronic Product Manufacturing"
# }
# Computer and Electronic Parts and Supplies Merchant Wholesalers
# {
#     "description": "CircuitSynergy: A trailblazing company specializing in the distribution of cutting-edge computer components and electronic parts, catering to tech-savvy businesses and enthusiasts.",
#     "names": [
#         "techsynergy",
#         "circuitcentral",
#         "componenthub",
#         "electroboost",
#         "synapseparts"
#     ],
#     "industry": "Computer and Electronic Parts and Supplies Merchant Wholesalers"
# }
# {
#     "description": "CircuitSolutions: A leading merchant wholesaler specializing in hard-to-find computer components and electronic parts, providing quick shipping and exceptional customer service.",
#     "names": [
#         "PartFinder",
#         "ElectroNexus",
#         "ComponentHub",
#         "CircuitCentral",
#         "TechScavenge"
#     ],
#     "industry": "Computer and Electronic Parts and Supplies Merchant Wholesalers"
# }
# {
#     "description": "Circuits & Components: A leading merchant wholesaler specializing in the distribution of high-quality computer and electronic parts and supplies. Our extensive inventory includes processors, memory modules, power supplies, graphics cards, and a wide range of other components. We pride ourselves on providing top-notch customer service, competitive pricing, and rapid order fulfillment. Our team of experts is always on hand to help customers find the perfect parts for their projects, ensuring their technology runs smoothly and efficiently.",
#     "names": [
#         "techtrade",
#         "partsplus",
#         "circuitsource",
#         "componenthub",
#         "electrodepot"
#     ],
#     "industry": "Computer and Electronic Parts and Supplies Merchant Wholesalers"
# }
# Computer and Software Stores
# {
#     "description": "TechSolution: A cutting-edge computer store specializing in custom-built gaming PCs, virtual reality systems, and software consulting services. Our team of experts provides personalized solutions to enhance your digital experience.",
#     "names": [
#         "TechBoost",
#         "GameGrid",
#         "VirtualVista",
#         "CustomCode",
#         "SolutionSphere"
#     ],
#     "industry": "Computer and Software Stores"
# }
# {
#     "description": "TechSolution: A cutting-edge computer store specializing in custom-built gaming PCs, virtual reality systems, and expert IT consulting services.",
#     "names": [
#         "TechBuild",
#         "VRHub",
#         "GameBoost",
#         "ITNexus",
#         "PCElite"
#     ],
#     "industry": "Computer and Software Stores"
# }
# {
#     "description": "TechSolution: A cutting-edge computer store specializing in custom-built gaming PCs, virtual reality systems, and software solutions for businesses. Our team of experts provides personalized consultations, installation services, and ongoing technical support.",
#     "names": [
#         "TechBoost",
#         "GameGrid",
#         "VRWorks",
#         "SolutionHub",
#         "CustomBuilds"
#     ],
#     "industry": "Computer and Software Stores"
# }
# Custom Computer Programming Services
# {
#     "description": "Intellitech Innovations: A leading-edge custom computer programming services company, delivering bespoke software solutions, system integrations, and cutting-edge applications to empower businesses and streamline operations.",
#     "names": [
#         "codecraft",
#         "techforge",
#         "innovatecode",
#         "logicflow",
#         "solutioncode"
#     ],
#     "industry": "Information Technology and Services"
# }
# {
#     "description": "Code Innovations: a trailblazing custom computer programming services company, delivering bespoke software solutions, system integrations, and cutting-edge applications to boost business efficiency and productivity.",
#     "names": [
#         "codebooster",
#         "techforge",
#         "innovatecode",
#         "softwaresynth",
#         "logicflow"
#     ],
#     "industry": "Information Technology and Services"
# }
# {
#     "description": "CodeGenius: A pioneering custom computer programming services company, delivering cutting-edge software solutions, tailored applications, and integrating advanced technologies for businesses to streamline operations, enhance productivity, and secure their digital future.",
#     "names": [
#         "CodeInnovate",
#         "TechSynergy",
#         "LogicFusion",
#         "ByteCrafters",
#         "IntelliSolve"
#     ],
#     "industry": "Information Technology and Services"
# }
# Data Processing, Hosting, and Related Services
# {
#     "description": "Introducing DataVault, a trailblazing company in the Data Processing, Hosting, and Related Services industry. We provide top-tier data security solutions, advanced analytics, and customized hosting services to help businesses unlock valuable insights from their data. Our team of data experts and engineers work tirelessly to ensure your data is protected, accessible, and actionable. With DataVault, you can focus on growing your business, while we take care of your data needs.",
#     "names": [
#         "DataGuard",
#         "InsightNest",
#         "AnalyticsVault",
#         "IntellectShelter",
#         "DataSanctuary"
#     ],
#     "industry": "Data Processing, Hosting, and Related Services"
# }
# {
#     "description": "DataVault Inc. is a cutting-edge tech company specializing in secure data processing, hosting, and related services. We provide businesses with customized solutions to manage and protect their digital assets, ensuring data privacy and efficiency. Our state-of-the-art data centers are equipped with advanced security measures, redundant power supplies, and high-speed connectivity to guarantee uninterrupted access and optimal performance. Our team of experts is dedicated to delivering personalized services tailored to each client's unique needs.",
#     "names": [
#         "DataGuard",
# ...
#     "names": [
#         "TalentTrail",
#         "EngageEvolve",
#         "DiversifyDynamics",
#         "PeoplePathways",
#         "HarmonyHire"
#     ],
#     "industry": "Human Resources Consulting Services"
# }
# {
#     "description": "EmpathyWorks: A compassionate human resources consulting firm specializing in employee well-being, mental health support, and organizational culture transformation.",
#     "names": [
#         "MindCareHR",
#         "CultureBoost",
#         "WellbeingWorks",
#         "MentalMentor",
#         "HappyHumanHR"
#     ],
#     "industry": "Human Resources Consulting Services"
# }
# Marketing Consulting Services
# {
#     "description": "BrandBoost: A marketing consulting firm specializing in strategic branding, innovative advertising campaigns, and data-driven consumer insights.",
#     "names": [
#         "brandspark",
#         "insightignite",
#         "adventive",
#         "campaigncraft",
#         "strategicspark"
#     ],
#     "industry": "Marketing Consulting Services"
# }
# {
#     "description": "BrandBoost: A marketing consulting firm specializing in strategic brand development, creative campaign execution, and data-driven performance analysis.",
#     "names": [
#         "brandspark",
#         "campaigncraft",
#         "insightignite",
#         "strategicspark",
#         "creativeflare"
#     ],
#     "industry": "Marketing Consulting Services"
# }
# {
#     "description": "BrandBoost: A marketing consulting firm specializing in strategic branding, creative campaign development, and data-driven audience engagement.",
#     "names": [
#         "BrandSpark",
#         "CampaignCraft",
#         "EngageInsight",
#         "StratagemBrand",
#         "DataDrivenMark"
#     ],
#     "industry": "Marketing Consulting Services"
# }
# Process, Physical Distribution, and Logistics Consulting Services
# {
#     "description": "OptimizeLogistics: A leading-edge consulting firm specializing in process improvement, physical distribution optimization, and logistics strategy for businesses of all sizes. Our team of experts leverages data analytics, technology solutions, and industry best practices to streamline operations, reduce costs, and enhance supply chain efficiency.",
#     "names": [
#         "StreamlineLogistics",
#         "OptiFlow",
#         "EffortlessSupply",
#         "LogiFlowPro",
#         "SupplySync"
#     ],
#     "industry": "Process, Physical Distribution, and Logistics Consulting Services"
# }
# {
#     "description": "OptimizeLogi is a leading process, physical distribution, and logistics consulting firm, specializing in streamlining supply chain operations, reducing costs, and enhancing efficiency for businesses. Our team of experts employs cutting-edge technology and data analysis to design customized solutions that address unique client challenges. From inventory management and transportation optimization to warehouse design and reverse logistics, we offer a comprehensive suite of services to ensure seamless flow of goods from origin to destination.",
#     "names": [
#         "FlowSynergy",
#         "LogiOptim",
#         "ChainCraft",
#         "LogiFlow",
#         "EffortLogi"
#     ],
#     "industry": "Process, Physical Distribution, and Logistics Consulting Services"
# }
# {
#     "description": "OptimizeLogistics: A trailblazing consulting firm specializing in process improvement, physical distribution optimization, and logistics strategy for businesses of all sizes. Our team of experts leverages data-driven insights and industry best practices to streamline operations, reduce costs, and enhance customer satisfaction.",
#     "names": [
#         "OptiFlow",
#         "LogiStream",
#         "SupplySync",
#         "FreightFusion",
#         "Distriboost"
#     ],
#     "industry": "Process, Physical Distribution, and Logistics Consulting Services"
# }
# Travel Arrangement and Reservation Services
# {
#     "description": "JourneyMate: A travel concierge company specializing in personalized itinerary planning, flight and hotel reservations, and destination experiences for adventurous souls.",
#     "names": [
#         "TripTailor",
#         "GlobeGuru",
#         "VoyageVista",
#         "WanderWise",
#         "TravelTwine"
#     ],
#     "industry": "Travel Arrangement and Reservation Services"
# }
# {
#     "description": "JourneyMate: A travel concierge company specializing in personalized itinerary planning, flight and hotel booking, and local experience curation for adventurous souls seeking authentic and immersive travel experiences.",
#     "names": [
#         "TravelTailor",
#         "AdventureCraft",
#         "VoyageWeaver",
#         "ExploreCraft",
#         "JourneyForge"
#     ],
#     "industry": "Travel Arrangement and Reservation Services"
# }
# {
#     "description": "JourneyMate: A travel concierge service providing personalized itineraries, flight and hotel bookings, and local experiences for globetrotters.",
#     "names": [
#         "TravelTailor",
#         "WanderPlanet",
#         "GlobeGuru",
#         "VoyageVista",
#         "TripTrailblazers"
#     ],
#     "industry": "Travel Arrangement and Reservation Services"
# }
# Security and Investigative Services
# {
#     "description": "Guardian Shield: A leading security and investigative services company, providing customized solutions for corporate, residential, and personal security. Our team of highly trained professionals specializes in risk assessment, executive protection, investigative research, and surveillance. With a commitment to innovation and excellence, we deliver peace of mind to our clients.",
#     "names": [
#         "ShieldGuard",
#         "SecureSentinel",
#         "VigilantVanguard",
#         "ProtectivePulse",
#         "SafeguardSolutions"
#     ],
#     "industry": "Security and Investigative Services"
# }
# {
#     "description": "Guardian Shield: A leading security and investigative services company, providing customized solutions for corporate, residential, and personal security. Our team of highly trained professionals specializes in risk assessment, executive protection, investigative research, and cybersecurity. With a commitment to innovation and excellence, we safeguard our clients' peace of mind and valuable assets.",
#     "names": [
#         "SecureSentry",
#         "ShieldGuard",
#         "VigilantVanguard",
#         "ProtectivePulse",
#         "SafeguardSynergy"
#     ],
#     "industry": "Security and Investigative Services"
# }
# {
#     "description": "Guardian Shield: A leading security and investigative services company, dedicated to safeguarding businesses and individuals through advanced surveillance technology, undercover investigations, and risk assessment solutions.",
#     "names": [
#         "ShieldSentry",
#         "GuardianEye",
#         "SecureScope",
#         "VigilantVision",
#         "RiskRadar"
#     ],
#     "industry": "Security and Investigative Services"
# }
# Drycleaning and Laundry Services
# {
#     "description": "SparkleShirts: A premier drycleaning and laundry services company, meticulously reviving your wardrobe with eco-friendly processes, state-of-the-art technology, and personalized care.",
#     "names": [
#         "ReviveRags",
#         "EcoLaundry",
#         "ShirtSaviors",
#         "LinenLeap",
#         "GreenPress"
#     ],
#     "industry": "Drycleaning and Laundry Services"
# }
# {
#     "description": "SparkleClean: A premier drycleaning and laundry services company, meticulously reviving your wardrobe with eco-friendly processes and impeccable attention to detail. Our state-of-the-art facilities utilize the latest technology to ensure your garments are not only spotless but also preserved for longevity.",
#     "names": [
#         "EcoLaundry",
#         "ReviveRags",
#         "GreenSuds",
#         "FreshFolds",
#         "PristinePress"
#     ],
#     "industry": "Drycleaning and Laundry Services"
# }
# {
#     "description": "SparkleShine: A premier drycleaning and laundry services company, specializing in eco-friendly processes, same-day turnaround, and luxury garment care.",
#     "names": [
#         "EcoLaundry",
#         "LuxeClean",
#         "GreenSparkle",
#         "QuickPress",
#         "PureLinen"
#     ],
#     "industry": "Drycleaning and Laundry Services"
# }
# Pet Care (excluding Veterinary)
# {
#     "description": "Pawsome Pad: A luxurious pet retreat providing custom-designed dog houses, cat trees, and outdoor playgrounds, crafted from eco-friendly materials.",
#     "names": [
#         "PawHaven",
#         "PetRetreat",
#         "EcoBark",
#         "GreenDen",
#         "FurryFort"
#     ],
#     "industry": "Pet Care"
# }
# {
#     "description": "Pawsome Haven: A luxurious pet resort and spa providing boarding, grooming, and enrichment programs for pampered pets, ensuring their comfort and happiness.",
#     "names": [
#         "PetLuxe",
#         "PawsParadise",
#         "FurryRetreat",
#         "GroomHounds",
#         "PetBliss"
#     ],
#     "industry": "Pet Care"
# }
# {
#     "description": "Pawsome Haven: A luxurious pet resort providing top-notch boarding, pampering grooming services, and enriching playtime experiences for pets.",
#     "names": [
#         "PetPamper",
#         "PawsitiveRetreat",
#         "FurryOasis",
#         "BarkBoutique",
#         "PetParadise"
#     ],
#     "industry": "Pet Care"
# }
# Vocational Rehabilitation Services
# {
#     "description": "EmpowerAbility: A pioneering vocational rehabilitation services company, dedicated to helping individuals with disabilities regain independence and employment through customized training programs, assistive technology solutions, and job placement services.",
#     "names": [
#         "AbilityBoost",
#         "EnableGrow",
#         "SkillEmpower",
#         "RehabRevive",
#         "EmpowerConnect"
#     ],
#     "industry": "Healthcare and Social Assistance"
# }
# {
#     "description": "EmpowerAbility: A pioneering vocational rehabilitation services company, transforming lives through customized training programs, employment placements, and disability management.",
#     "names": [
#         "AbilityBoost",
#         "SkillEmpower",
#         "LifeTransform",
#         "EnableGrowth",
#         "CareerCraft"
#     ],
#     "industry": "Health and Social Services"
# }
# {
#     "description": "EmpowerAbility: A pioneering vocational rehabilitation services company, dedicated to transforming lives through personalized training programs, employment placement, and disability management.",
#     "names": [
#         "AbilityBoost",
#         "EmpowerTrain",
#         "SkillRevive",
#         "LifeReconnect",
#         "EnableCareers"
#     ],
#     "industry": "Health and Social Services"
# }
# Services for the Elderly and Disabled
# {
#     "description": "Compassionate Care Homes: A leading provider of personalized in-home care services for the elderly and disabled, offering assistance with daily living activities, medication management, and companionship.",
#     "names": [
#         "ElderNest",
#         "ComfortCare",
#         "CareConnect",
#         "SeniorSolace",
#         "AbilityAssist"
#     ],
#     "industry": "Services for the Elderly and Disabled"
# }
# {
#     "description": "Compassionate Care Homes: A leading provider of personalized in-home care services for the elderly and disabled, offering assistance with daily living activities, medical care, and social engagement.",
#     "names": [
#         "CareCompanion",
#         "ElderEase",
#         "HomeHelpHeroes",
#         "SeniorSolutions",
#         "ComfortCareNet"
#     ],
#     "industry": "Services for the Elderly and Disabled"
# }
# {
#     "description": "Compassionate Care Homes: A premier service provider specializing in customized eldercare and disability solutions, offering daily living assistance, skilled nursing, therapy services, and social engagement programs.",
#     "names": [
#         "ElderEase",
#         "CareConnect",
#         "ComfortCare",
#         "SeniorSolutions",
#         "AbilityAssist"
#     ],
#     "industry": "Services for the Elderly and Disabled"
# }
# Child Day Care Services
# {
#     "description": "Little Wonders Daycare: A nurturing and stimulating environment where children aged 0-5 years old are cared for by experienced and loving educators. Our core services include full-time and part-time care, nutritious meals, developmentally appropriate activities, and open communication with parents. We believe in creating a home-like atmosphere that fosters curiosity, creativity, and social skills.",
#     "names": [
#         "WonderCare",
#         "LittleNest",
#         "ChildBlossom",
#         "EduNest",
#         "GrowKids"
#     ],
#     "industry": "Child Day Care Services"
# }
# {
#     "description": "Sunny Smiles Daycare: A warm and nurturing environment where little ones thrive, offering customized care programs, nutritious meals, and age-appropriate activities to foster early learning and development.",
#     "names": [
#         "littlesprouts",
#         "kidscottage",
#         "imaginationstation",
#         "tendercare",
#         "littleacorns"
#     ],
#     "industry": "Child Day Care Services"
# }
# {
#     "description": "Little Wonders Daycare: A nurturing and educational child care center where children thrive through play-based learning, nutritious meals, and loving care from dedicated and experienced teachers.",
#     "names": [
#         "WonderNest",
#         "LittleLearners",
#         "PlayfulMinds",
#         "NurtureNest",
#         "EdVentureKids"
#     ],
#     "industry": "Child Day Care Services"
# }
# Religious (except Schools) and Welfare Activities
# {
#     "description": "SacredSoil: A compassionate organization dedicated to uplifting communities through spiritual counseling, crisis intervention, and charitable outreach programs.",
#     "names": [
#         "SacredSphere",
#         "HealingHaven",
#         "DivineDynamics",
#         "CompassionConnect",
#         "FaithfulFoundation"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# {
#     "description": "SacredSolace: A compassionate organization providing spiritual counseling, community outreach programs, and crisis intervention services.",
#     "names": [
#         "SolaceSpark",
#         "HealingHaven",
#         "FaithFusion",
#         "DivineDwelling",
#         "CompassionCrest"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# {
#     "description": "A compassionate organization providing spiritual counseling, community outreach programs, and crisis intervention services. Our team of dedicated clergy and social workers offer guidance and support to individuals and families in need.",
#     "names": [
#         "soulshelter",
#         "healinghaven",
#         "spiritspace",
#         "communitycare",
#         "hopehouse"
#     ],
#     "industry": "Religious (except Schools) and Welfare Activities"
# }
# Gambling Industries.
# {
#     "description": "Lucky Stars Casino: A dazzling virtual gaming paradise, where fortune favors the bold. Offering an extensive collection of online slots, table games, live dealer experiences, and daily promotions to bring excitement and potential winnings to every player.",
#     "names": [
#         "StellarCasino",
#         "FortuneGames",
#         "RollTheDice",
#         "LuckyDraw",
#         "CasinoNight"
#     ],
#     "industry": "Gambling Industries"
# }
# {
#     "description": "Lucky7 Casino: A high-rolling establishment offering an immersive gambling experience with a wide range of table games, slot machines, and live dealer options. Our state-of-the-art casino features a grand ballroom, private VIP rooms, and world-class customer service. Enjoy delicious cuisine and premium drinks at our on-site restaurant and bar. Join our exclusive loyalty program for special perks and promotions.",
#     "names": [
#         "CasinoFortune",
#         "LuckyRoller",
#         "GamblePalace",
#         "TableVibes",
#         "WinSphere"
#     ],
#     "industry": "Gambling"
# }
# {
#     "description": "Lucky Stars Casino: A high-rolling establishment offering an unforgettable gaming experience with a vast selection of table games, slot machines, and a luxurious VIP lounge. Our state-of-the-art security ensures a safe and fair environment for all our esteemed guests.",
#     "names": [
#         "gamblersden",
#         "luckypoint",
#         "stellarcasino",
#         "roulettesplash",
#         "jackpotjunction"
#     ],
#     "industry": "Gambling Industries"
# }

# %% [markdown]
# # Full dataset generation

# %%
def get_one_random_example_for_industry(industry, reference):
    # Filter examples for the given industry with valid JSON responses
    industry_examples = [
        example for example in reference
        if example['response']['industry'] == industry and example['JSON'] == 'YES'
    ]

    # Randomly choose one example from the filtered list, or take what's available
    chosen_example = random.choice(industry_examples) if industry_examples else None

    # Prepare the output by selecting only the 'description' and 'names' keys
    formatted_example = None
    if chosen_example:
        formatted_example = {
            "description": chosen_example['response']['description'],
            "names": chosen_example['response']['names']
        }
    return formatted_example

# %%
# Initialize storage for results
all_results = []
all_raw = []

# Number of times to run query for each industry
# Run until 5000 records are produced
num_queries = round(5000/len(industries))

# Base prompt template with placeholders for examples and industry
base_prompt_template = """
Generate a single detailed and creative business description for a company in the {industry} industry, followed by five unique website name suggestions. The names should be relevant to the business description and business name if provided, focusing on the core services or products offered. The names should not include domain extensions like .com or prefixes like www. Ensure each business name is a single word or a creative combination of words that could potentially be used as a domain name. Provide the business description and the five suggested names in a JSON format.

Here is a response format example:
{examples}


"""

# %%
# Main dataset generation
# checks for valid json output pattern and keeps ratio fixed for all industries

# Iterate through each industry
for industry in industries:
    print(industry)  # For debugging

    valid_json_count = 0  # Counter for valid JSON responses
    total_attempts = 0  # Counter for total attempts, including invalid responses

    while valid_json_count < num_queries:  # Run until valid JSON responses reach num_queries
        total_attempts += 1  # Increment total attempts each iteration

        # Fetch a new example for each run
        chosen_example = get_one_random_example_for_industry(industry, sample_results)
        examples_str = ""
        if chosen_example:
            # Format the single example for inclusion in the prompt
            formatted_example = json.dumps(chosen_example, indent=2)
            examples_str = formatted_example

        # Update content for each query to include the new example
        content = base_prompt_template.format(industry=industry, examples=examples_str)
        messages = [ChatMessage(role="user", content=content)]

        chat_response = client.chat(model=model, messages=messages, max_tokens=200, temperature=0.3)

        # Store the raw chat response content
        response_content = chat_response.choices[0].message.content if chat_response.choices else "No response"
        print(response_content)

        try:
            response_dict = json.loads(response_content)
            json_status = "YES"
            valid_json_count += 1  # Only increment valid_json_count if JSON is valid

            response_dict['industry'] = industry  # Add the industry to the result
        except (json.JSONDecodeError, ValueError) as e:
            json_status = "NO"
            response_dict = {"error": f"Failed to process response: {e}", "industry": industry}

        result_record = {
            "response": response_dict,
            "JSON": json_status,
            "attempt": total_attempts,  # Track the attempt number for debugging or analysis
        }

        all_results.append(result_record)  # Add the result record to the all_results list
        all_raw.append(chat_response)

    print(f"Industry: {industry}, Valid JSON Count: {valid_json_count}, Total Attempts: {total_attempts}")
    # Reset the counters for the next industry
    valid_json_count = 0
    total_attempts = 0
# Out:
# Streaming output truncated to the last 5000 lines.
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products in various industries. Our cutting-edge facilities and team of certified engineers provide comprehensive testing services, including functional testing, safety certifications, and performance analysis. By partnering with TechGuard, clients can deliver high-quality, secure, and compliant technology solutions to their customers.",
#   "names": [
#     "CertiShield",
#     "TechSafeLabs",
#     "ReliabilityHub",
#     "SafetyTestPro",
#     "ComplianceGuard"
#   ]
# }
# {
#   "description": "Veracity Labs: A pioneering testing laboratory dedicated to uncovering truth and ensuring reliability in various industries. Our team of meticulous scientists employs advanced technologies to analyze and validate the authenticity of consumer goods, food and beverages, pharmaceuticals, and environmental samples. With a commitment to transparency and accuracy, Veracity Labs empowers businesses to make informed decisions and uphold the trust of their customers.",
#   "names": [
#     "TruthTest",
#     "ReliabilityHub",
#     "VeracityVista",
#     "AuthenticityAnnex",
#     "IntegrityInsights"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products in the ever-evolving digital world. Our team of engineers and scientists employ cutting-edge technology and rigorous testing protocols to identify potential issues and provide actionable solutions, enabling our clients to deliver high-quality, dependable technology to their customers.",
#   "names": [
#     "Reliabit",
#     "TechVerify",
#     "SafetySphere",
#     "InnovateTest",
#     "DependableDote"
#   ]
# }
# {
#   "description": "TechNexus Labs: A pioneering testing laboratory that pushes the boundaries of innovation in the tech industry. Our advanced facilities and team of scientists provide comprehensive testing solutions for electronics, software, and materials. With a focus on speed, accuracy, and reliability, we empower businesses to bring cutting-edge products to market and maintain a competitive edge.",
#   "names": [
#     "NexusTest",
#     "TechSolve",
#     "InnoScan",
#     "ElectroCheck",
#     "PrecisionLabs"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory providing comprehensive analysis and certification services for technology products in the fields of telecommunications, software, and consumer electronics. Our team of skilled engineers and technicians utilizes advanced testing equipment and methodologies to ensure the highest quality and reliability for our clients' innovations.",
#   "names": [
#     "TechCert",
#     "QualiTech",
#     "TestNexus",
#     "InnovationCheck",
#     "ReliabilityRating"
#   ]
# }
# {
#   "description": "Precision Insights: A premier testing laboratory offering comprehensive analysis for various industries including automotive, consumer goods, and pharmaceuticals. Our team of highly skilled scientists and engineers employ cutting-edge technology to deliver precise and reliable results, enabling our clients to optimize product performance, ensure quality, and maintain regulatory compliance.",
#   "names": [
#     "TestPrecision",
#     "InsightLab",
#     "QualityCheckpoint",
#     "ComplianceSolutions",
#     "PureAnalyze"
#   ]
# }
# {
#   "description": "Comprehensive Testing Solutions: A pioneering laboratory dedicated to ensuring product and material integrity through rigorous testing and analysis. Our team of highly skilled scientists and engineers employ cutting-edge technology to provide actionable insights for various industries, including electronics, food, and pharmaceuticals. With a commitment to accuracy, timeliness, and transparency, we empower our clients to make informed decisions and maintain the highest standards of safety and quality.",
#   "names": [
#     "IntegrityLab",
#     "ScienceSafeguard",
#     "TestTrust",
#     "QualityQuants",
#     "PrecisionPioneers"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products in the ever-evolving digital world. Our advanced facilities and team of engineers provide comprehensive testing services, from hardware durability to software compatibility, enabling our clients to deliver high-quality tech solutions to their customers.",
#   "names": [
#     "TechSure",
#     "Reliabit",
#     "TestTechPro",
#     "SafetyScan",
#     "InnovateTest"
#   ]
# }
# {
#   "description": "TechnoVerity Labs: Pioneering the future of testing, we provide cutting-edge solutions for businesses seeking to validate their electronic products and software. Our team of dedicated engineers and scientists utilize advanced equipment and techniques to ensure the utmost reliability and functionality, allowing our clients to bring their innovations to market with confidence. From consumer electronics to industrial automation, our comprehensive testing services cover it all.",
#   "names": [
#     "TechnoTest",
#     "ElectroCheck",
#     "InnovationVerified",
#     "ReliabilityHub",
#     "CircuitSafety"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products in the ever-evolving digital world. Our team of engineers and scientists employ cutting-edge techniques to analyze and certify electronic devices, software, and networks, providing peace of mind for businesses and consumers alike.",
#   "names": [
#     "CertiShield",
#     "TechSafeguard",
#     "ReliabilityHub",
#     "TestTechPro",
#     "InnovateProtect"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products through rigorous testing and analysis. Our team of engineers and scientists employ cutting-edge techniques to identify potential issues and provide actionable solutions, allowing our clients to bring high-quality tech to market with confidence. From consumer electronics to industrial equipment, TechGuard is your trusted partner in tech testing.",
#   "names": [
#     "Reliabit",
#     "TechVerify",
#     "SafetyNetLabs",
#     "TestTechPro",
#     "InnovateQC"
#   ]
# }
# {
#   "description": "TechnoVerity Labs: Pioneering the future of testing, we offer a comprehensive suite of services in material and product analysis, microbiology, and environmental testing. Our advanced facilities and team of dedicated scientists deliver precise and timely results, empowering businesses to make informed decisions, ensure product safety, and maintain regulatory compliance.",
#   "names": [
#     "TechnoTest",
#     "VerityLabs",
#     "MicroSafety",
#     "AdvancedAnalysis",
#     "ScienceSynergy"
#   ]
# }
# {
#   "description": "TechSafe: A pioneering testing laboratory dedicated to ensuring the safety and reliability of technology products in the ever-evolving digital landscape. Our team of experts meticulously analyzes electronic components, software, and systems to identify vulnerabilities and provide actionable solutions, empowering businesses to deliver secure and high-performing technology to their customers.",
#   "names": [
#     "SecureCheck",
#     "TechGuard",
#     "ReliabilityHub",
#     "SafetyNexus",
#     "TrustTest"
#   ]
# }
# {
#   "description": "TechnoVerity Labs: A pioneering testing laboratory that pushes the boundaries of innovation, offering a wide range of services from software testing to material analysis. Our team of dedicated engineers and scientists employ cutting-edge technology to deliver precise and timely results, enabling our clients to bring their products to market with confidence and assurance. With a focus on continuous improvement and a commitment to excellence, TechnoVerity Labs is the go-to partner for businesses seeking to elevate their quality standards.",
#   "names": [
#     "TechnoTest",
#     "VerityLabs",
#     "InnoQuality",
#     "TestInnovate",
#     "PrecisionPioneers"
#   ]
# }
# {
#   "description": "TechGuard: A premier testing laboratory dedicated to ensuring the reliability and safety of technology products for businesses and consumers. Our cutting-edge facilities and team of engineers provide comprehensive testing services, from software compatibility to hardware durability, allowing our clients to deliver high-quality tech solutions with peace of mind.",
#   "names": [
#     "TechSure",
#     "Reliabit",
#     "TestTechPro",
#     "SafetyScan",
#     "GaurdianQA"
#   ]
# }
# Industry: Testing Laboratories, Valid JSON Count: 25, Total Attempts: 25
# Medical and Diagnostic Laboratories
# {
#   "description": "Innovative medical diagnostics lab, PrecisionHealth, offers advanced genetic testing, personalized treatment plans, and groundbreaking research in the field of molecular diagnostics and precision medicine, empowering healthcare providers to make informed decisions and ultimately improve patient outcomes.",
#   "names": [
#     "MoleculeMaster",
#     "GeneSpectrum",
#     "PrecisionProbe",
#     "HealthSleuth",
#     "MolecularMystic"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, Pathfinders, dedicated to precision medicine through advanced genetic testing, personalized treatment plans, and groundbreaking research in the field of neurodegenerative diseases.",
#   "names": [
#     "NeuroGenesis",
#     "BrainTrailblazers",
#     "GenePathfinders",
#     "NeuroSolution",
#     "CognitiveCompass"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathoGenius, offers personalized and precise diagnostic solutions using advanced genomic technologies, AI-powered analysis, and expert consultations for customized treatment plans.",
#   "names": [
#     "GenoGenius",
#     "DiagNome",
#     "BioSpectrum",
#     "GeneMap",
#     "CureCode"
#   ]
# }
# {
#   "description": "CureSpectrum: A pioneering medical laboratory dedicated to revolutionizing diagnostics through innovative technologies and expert analysis, offering comprehensive testing solutions for various conditions including infectious diseases, genetic disorders, and cancer, enabling healthcare professionals and patients to make informed decisions for effective treatment and improved health outcomes.",
#   "names": [
#     "InnoLabs",
#     "BioDiscoveries",
#     "DiagnosticsRevolution",
#     "HealthSpectrum",
#     "GenomeInsights"
#   ]
# }
# {
#   "description": "Precision Diagnostics: Pioneering the Future of Healthcare with advanced molecular testing, personalized treatment plans, and dedicated patient care in a state-of-the-art facility.",
#   "names": [
#     "MoleculeMasters",
#     "GeneGuardian",
#     "BioSpectrum",
#     "CellularCare",
#     "DiagnoDNA"
#   ]
# }
# {
#   "description": "Precision Diagnostics: Pioneering the Future of Healthcare with advanced molecular testing, personalized treatment plans, and dedicated patient care in a state-of-the-art facility.",
#   "names": [
#     "MolecuCare",
#     "GeneGuardian",
#     "BioSynergy",
#     "CellVision",
#     "PathoPulse"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathfindersLab, dedicated to transforming patient care through advanced molecular testing, rapid results, and collaborative research with healthcare providers for personalized treatment plans.",
#   "names": [
#     "MolecularPathfinders",
#     "SwiftDiagLab",
#     "CollaborativeCures",
#     "GeneticInsights",
#     "PersonalizedPrecision"
#   ]
# }
# {
#   "description": "Precision Diagnostics: Pioneering the future of healthcare with advanced molecular testing, personalized treatment plans, and dedicated patient support in a state-of-the-art facility.",
#   "names": [
#     "MolecuCare",
#     "GeneSpectrum",
#     "BioSignature",
#     "CellularInsight",
#     "AdvanceMolecule"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, Pathfinders, offers accurate and timely diagnostic services using advanced technologies and expert analysis, delivering personalized treatment plans and peace of mind to patients.",
#   "names": [
#     "DiagnoPath",
#     "TechTest",
#     "ExpertAnalsis",
#     "BioSolutions",
#     "PrecisionPath"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathfindersLab, dedicated to transforming patient care through advanced molecular testing, rapid results, and collaborative care for complex conditions.",
#   "names": [
#     "MolecularPath",
#     "AdvancedTestTech",
#     "SwiftDiagLab",
#     "CollaborativeCures",
#     "GeneticTrailblazers"
#   ]
# }
# {
#   "description": "SynapseLabs: Pioneering the future of medical diagnostics with AI-powered analysis, rapid turnaround times, and a comprehensive range of tests including genetics, pathology, and toxicology.",
#   "names": [
#     "SynapseDiag",
#     "BrainScanAI",
#     "SwiftTestLabs",
#     "GenoSolution",
#     "NeuroNexusLabs"
#   ]
# }
# {
#   "description": "ReviveLabs: A pioneering medical diagnostic laboratory dedicated to revolutionizing patient care through innovative and precise diagnostic solutions. Utilizing state-of-the-art technologies and a team of expert scientists, we provide rapid and accurate testing for a wide range of conditions, from common infections to complex genetic disorders and chronic diseases. Our mission is to empower healthcare providers with actionable insights to make informed decisions and improve patient outcomes.",
#   "names": [
#     "InnoLabs",
#     "ReviveSciences",
#     "PrecisionDiagnostics",
#     "AdvanceTestings",
#     "GenoRevive"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, Pathfinders, offering precision testing, rapid results, and expert consultation for a wide range of medical conditions, including infectious diseases, genetic disorders, and complex health issues.",
#   "names": [
#     "PathfinderLabs",
#     "PrecisionTest",
#     "RapidResultRx",
#     "ExpertConsultMD",
#     "ComplexCureCo"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PrecisionPath, offers personalized care through advanced genomic testing, customized treatment plans, and pioneering research in molecular diagnostics and theranostics.",
#   "names": [
#     "MolecuRx",
#     "GeneSpectrum",
#     "Pathogenesis",
#     "BioSignature",
#     "CellularInsights"
#   ]
# }
# {
#   "description": "Precision Diagnostics: Pioneering the future of healthcare with advanced molecular testing, personalized treatment plans, and dedicated patient support in a state-of-the-art facility.",
#   "names": [
#     "MolecuCare",
#     "GeneSpectrum",
#     "BioSignature",
#     "CellularInsight",
#     "AdvanceMolecule"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathfindersLab, dedicated to transforming patient care through advanced molecular testing, rapid results, and collaborative care for complex conditions.",
#   "names": [
#     "MolecularMap",
#     "SwiftDiagnostics",
#     "CollaborativeCures",
#     "GeneticInsights",
#     "AdvancedSpectrum"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathoGenius, offers personalized healthcare solutions through advanced genomic testing, AI-driven analysis, and customized treatment plans, revolutionizing disease management and improving patient outcomes.",
#   "names": [
#     "GenomeSpectrum",
#     "DiagNexus",
#     "BioSynapse",
#     "GeneTrailblazers",
#     "CureCognition"
#   ]
# }
# {
#   "description": "CureSpectrum: A pioneering medical laboratory dedicated to revolutionizing patient care through comprehensive diagnostic services, integrating genomic, proteomic, and metabolomic analysis for personalized treatment plans. Leveraging state-of-the-art technology and a team of expert scientists, CureSpectrum delivers timely and precise results to healthcare providers, empowering them to make informed decisions and improve patient outcomes.",
#   "names": [
#     "GenomePrecision",
#     "ProteoInsights",
#     "MetaboSolutions",
#     "BioDiscoveryLab",
#     "PersonalizedDiagnostics"
#   ]
# }
# {
#   "description": "CureSpectrum: A pioneering medical laboratory dedicated to revolutionizing disease diagnosis through innovative genetic testing, biomarker analysis, and cutting-edge technologies. Our team of expert scientists and technicians collaborate with healthcare professionals to provide swift, accurate, and comprehensive diagnostic solutions, empowering them to make informed decisions for their patients' treatment and wellbeing.",
#   "names": [
#     "GenoSpectrum",
#     "BioMarkerSolutions",
#     "DiagNoseGenius",
#     "InnovativeTests",
#     "GeneInsights"
#   ]
# }
# {
#   "description": "CureSpectrum: A pioneering medical laboratory dedicated to revolutionizing disease diagnosis through innovative genetic testing, biochemical analysis, and molecular pathology. Leveraging state-of-the-art technologies and a team of expert scientists, CureSpectrum delivers precise and timely results to healthcare professionals and patients, empowering them to make informed treatment decisions and improve overall health outcomes.",
#   "names": [
#     "GenoDiscover",
#     "BioSignature",
#     "DxInnovations",
#     "MolecularTrailblazers",
#     "CureGenetics"
#   ]
# }
# {
#   "description": "CureSpectrum: A pioneering medical laboratory dedicated to revolutionizing diagnostics through innovative technologies and expert analysis, providing comprehensive testing solutions for a wide range of medical conditions, from common infections to complex genetic disorders and rare diseases, empowering healthcare professionals with actionable insights for personalized treatment plans.",
#   "names": [
#     "InnovateDiagnostics",
#     "GenoSpectrum",
#     "BioDiscoveries",
#     "TestTrailblazers",
#     "CureInsights"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PathfindersLab, dedicated to transforming patient care through advanced molecular testing, precision medicine, and groundbreaking research in infectious and genetic diseases.",
#   "names": [
#     "MolecularPath",
#     "PrecisionDiag",
#     "GenomeTrailblazer",
#     "InfectiousInsight",
#     "GeneSleuth"
#   ]
# }
# {
#   "description": "Introducing BioNexus, a state-of-the-art medical diagnostics lab dedicated to transforming patient care through advanced molecular testing, AI-driven analysis, and collaborative care. Our team of experts leverages the power of genomic sequencing, proteomics, and metabolomics to deliver accurate diagnoses and personalized treatment plans for a wide range of conditions, from common diseases to rare and complex disorders. By combining cutting-edge research, innovative technology, and a compassionate approach, BioNexus empowers healthcare providers and patients to take control of their health journeys.",
#   "names": [
#     "MolecularPrecision",
#     "GenomeSynergy",
#     "BioDiscoveryHub",
#     "ProteomePioneer",
#     "HealthSpectrumLabs"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, PrecisionPath, offers personalized healthcare solutions through advanced genomic testing, molecular diagnostics, and research-driven theranostics.",
#   "names": [
#     "GenomeSpectrum",
#     "MoleculeMind",
#     "BioSignature",
#     "GeneTrailblazers",
#     "PathoGenius"
#   ]
# }
# {
#   "description": "Innovative medical diagnostics lab, BioScience Hub, dedicated to delivering accurate and timely results through advanced technologies and expert analysis in the fields of molecular pathology, genetic testing, and infectious diseases.",
#   "names": [
#     "BioScienceSolutions",
#     "MolecularInsights",
#     "PathoGenius",
#     "GeneAdvance",
#     "InfectoCheck"
#   ]
# }
# Industry: Medical and Diagnostic Laboratories, Valid JSON Count: 25, Total Attempts: 25
# Architectural, Engineering, and Related Services
# {
#   "description": "Innovative design studio merging architectural brilliance, structural ingenuity, and technological advancements to craft future-ready spaces. Our team of visionary engineers and architects meticulously blend form and function, delivering structures that are not only aesthetically pleasing but also energy-efficient and sustainable.",
#   "names": [
#     "FutureFormDesigns",
#     "EcoTechArchitects",
#     "SustainableSynergyCo",
#     "GreenInnovationHub",
#     "TechSavvyBuilds"
#   ]
# }
# {
#   "description": "Visionary Build Solutions: A premier architectural and engineering firm, integrating advanced technology, sustainable practices, and creative design to deliver innovative structural solutions, transforming ideas into functional and visually stunning structures.",
#   "names": [
#     "InnovArch",
#     "TechStructure",
#     "DesignSynergy",
#     "ArchTechFusion",
#     "SustainableSolutions"
#   ]
# }
# {
#   "description": "Introducing 'VisionarySpatialDesigns', a dynamic architectural firm dedicated to transforming spaces with a focus on functional innovation, structural integrity, and aesthetic harmony. Our team of visionary architects and engineers excel in creating sustainable designs that seamlessly blend form and function, delivering exceptional solutions for commercial, residential, and institutional projects. From concept to completion, we prioritize collaboration, sustainability, and excellence, ensuring that each project is a testament to our commitment to creating inspiring and enduring spaces.",
#   "names": [
#     "VisionarySpatial",
#     "FunctionalHarmony",
#     "InnovativeDesignBuild",
#     "ArchitecturalPioneers",
#     "SustainableDesignHub"
#   ]
# }
# {
#   "description": "Visionary Build Solutions: A premier architectural and engineering firm, delivering innovative design, structural analysis, and construction solutions for commercial and residential projects, ensuring functionality, sustainability, and aesthetic appeal.",
#   "names": [
#     "InnovArch",
#     "BuildSynergy",
#     "DesignSolve",
#     "ArchitectureBoost",
#     "EngineerElevate"
#   ]
# }
# {
#   "description": "Visionary Build Solutions: A premier architectural, engineering, and related services firm, delivering innovative designs and solutions for commercial and residential projects, focusing on structural integrity, energy efficiency, and sustainable materials.",
#   "names": [
#     "StructuralVision",
#     "EcoSynergy",
#     "BuildInnovate",
#     "DesignEfficiency",
#     "SustainableSolutions"
#   ]
# }
# {
#   "description": "Visionary Build Solutions: A premier architectural and engineering firm, delivering innovative structural designs, mechanical engineering expertise, and sustainable solutions to create functional, efficient, and visually stunning buildings.",
#   "names": [
#     "StructuralVision",
#     "BuildInnovate",
#     "EngineeredElegance",
#     "ArchitecturalSynergy",
#     "DesignPrecision"
#   ]
# }
# {
#   "description": "Introducing 'VisionarySpaces', a dynamic architectural firm that merges art and science to create innovative, functional, and sustainable buildings. Our team of visionary architects and engineers excel in designing state-of-the-art structures, implementing advanced engineering solutions, and integrating technology to enhance the user experience. We are committed to creating spaces that inspire, empower, and foster growth, all while minimizing our environmental footprint.",
#   "names": [
#     "VisionaryArchitects",
#     "InnovativeBuildDesign",
#     "ArtScienceSpaces",
#     "SustainableDesignHub",
#     "TechEnabledBuilds"
#   ]
# }
# {
#   "description": "Innovative design studio merging architectural brilliance, engineering precision, and biophilic design to craft breathtaking, sustainable spaces. Our team of visionary architects and engineers meticulously weave natural elements into structures, ensuring harmony between built environments and the natural world.",
#   "names": [
#     "NatureWeaveDesigns",
#     "BioArchitectsCollective",
#     "EcoSynergyBuild",
#     "GreenSpaceEngineering",
#     "BiodynamicDesignWorks"
#   ]
# }
# {
#   "description": "Innovative design studio merging architectural brilliance, engineering precision, and biophilic design principles to craft breathtaking, eco-conscious structures. Our team of visionaries collaborate with clients to create harmonious spaces that blend art, science, and nature.",
#   "names": [
#     "NatureCraftDesign",
#     "EcoArtitects",
#     "BioBuildCo",
#     "GreenVisionDesigns",
#     "SustainableMasterpiece"
#   ]
# }
# {
#   "description": "Innovative studio merging architectural elegance, structural ingenuity, and sustainable practices to craft future-ready spaces. Our team of visionaries and problem-solvers work in tandem with clients to design functional, eco-friendly structures that seamlessly blend with nature and stand the test of time.",
#   "names": [
#     "ArchitectureNexus",
#     "EcoStructSolutions",
#     "SustainableArchitects",
#     "GreenBuildCraftsmen",
#     "InnovativeEcoDesign"
#   ]
# }
# {
#   "description": "Visionary Build: A premier architectural firm integrating advanced engineering solutions, innovative construction techniques, and inspiring design to create functional and beautiful buildings that stand the test of time.",
#   "names": [
#     "EngineeredVision",
#     "BuildInnovate",
#     "ArchitectureFusion",
#     "InnovateConstruct",
#     "DesignSynergy"
#   ]
# }
# {
#   "description": "Innovative design studio merging architectural vision, structural ingenuity, and sustainable practices to craft future-ready spaces. Our team of architects and engineers meticulously blend form and function, integrating advanced technology and eco-conscious materials to create harmonious, resilient structures.",
#   "names": [
#     "FutureFormDesign",
#     "EcoTechBuild",
#     "SustainableSynergyCo",
#     "ArchitecturalResilience",
#     "GreenTechStructures"
#   ]
# }
# {
#   "description": "Visionary Build Solutions: A premier architectural firm offering integrated design, engineering, and construction services, delivering innovative and sustainable solutions for commercial and residential projects.",
#   "names": [
#     "InnoBuild",
#     "ArchitectureSynergy",
#     "DesignEngine",
#     "ConstructiveSolutions",
#     "IntegratedBuild"
#   ]
# }
# {
#   "description": "Introducing 'VisionarySpaces', a leading Architectural, Engineering, and Related Services firm, delivering innovative design solutions that harmonize function, aesthetics, and sustainability. Our team of experts specializes in eco-friendly designs, structural engineering, and cutting-edge technology integration for commercial and residential projects. We pride ourselves on creating inspiring, energy-efficient spaces that enhance the quality of life and contribute to a greener future.",
#   "names": [
#     "EcoVisionary",
#     "GreenSpaceDesign",
#     "SustainableVision",
#     "InnovateGreen",
#     "EcoTechSpaces"
#   ]
# }
# {
#   "description": "Introducing 'VisionarySpatialDesigns', a dynamic architectural firm that seamlessly blends art and science to create innovative, functional, and aesthetically pleasing spaces. Our team of experts specializes in structural engineering, interior design, and landscape architecture, offering comprehensive solutions for both residential and commercial projects. With a focus on sustainability and energy efficiency, we strive to minimize our clients' carbon footprint while maximizing their living or working experience.",
#   "names": [
#     "VisionarySpatialSolutions",
#     "ArtScienceDesignBuild",
#     "EcoEleganceArchitects",
#     "SustainableSpaceDesign",
#     "GreenBuildVisionaries"
#   ]
# }
# {
#   "description": "Visionary Build: A premier architectural firm delivering innovative solutions in structural engineering, mechanical, electrical, and plumbing engineering, and interior design, creating functional and visually stunning buildings.",
#   "names": [
#     "InnovArch",
#     "BuildSynergy",
#     "MEPDesignHub",
#     "StructuralVision",
#     "DesignNexus"
#   ]
# }
# {
#   "description": "Introducing 'VisionarySpaces', a dynamic architectural firm dedicated to transforming your vision into reality. Our team of creative architects and engineers excel in designing functional and aesthetically pleasing structures, focusing on energy efficiency, sustainable materials, and innovative technology integration. From concept to completion, we provide comprehensive design solutions for both residential and commercial projects.",
#   "names": [
#     "VisionaryArchitects",
#     "EcoTechDesigns",
#     "InnovativeBuildSolutions",
#     "GreenSpaceEngine",
#     "SustainableVisionaries"
#   ]
# }
# {
#   "description": "Visionary Build: A dynamic architectural firm offering integrated solutions in structural engineering, mechanical, electrical, and plumbing engineering, and interior design, delivering functional, sustainable, and aesthetically stunning structures.",
#   "names": [
#     "IntegratedBuild",
#     "ArchitecturalSynergy",
#     "MEPDesignPro",
#     "StructuralVision",
#     "InnovateConstruct"
#   ]
# }
# {
#   "description": "Innovative design studio merging architectural brilliance, structural ingenuity, and technological advancements to craft future-ready spaces. Our team of visionary engineers and architects meticulously blend form and function, delivering aesthetically pleasing and sustainable solutions for commercial and residential projects.",
#   "names": [
#     "FutureFormDesigns",
#     "TechnoSpaceCraft",
#     "SustainableSynergyCo",
#     "ArchitecturalAdvancements",
#     "InnovativeInfrastructure"
#   ]
# }
# {
#   "description": "Revolutionary Design Collective, merging art and science to deliver architectural masterpieces, structural innovations, and engineering marvels, with a focus on community-centric and technologically advanced projects.",
#   "names": [
#     "ArchitecturalRevolution",
#     "InnovationNexusDesign",
#     "CommunityTechDesign",
#     "DesignPioneersCollective",
#     "ArchitecturalInnovators"
#   ]
# }
# {
#   "description": "Introducing 'VisionaryBuild', a trailblazing Architectural, Engineering, and Related Services firm, dedicated to transforming spaces with a focus on functional art, cutting-edge technology, and sustainability. Our team of visionary architects and engineers meticulously craft innovative designs that seamlessly blend form and function, while prioritizing the use of eco-friendly materials and energy-efficient solutions. From concept to completion, VisionaryBuild's commitment to excellence ensures that every project is not just a building, but a work of art that stands the test of time.",
#   "names": [
#     "FunctionalArtistry",
#     "EcoTechDesigns",
#     "SustainableVisionaries",
#     "ArtfulEngineering",
#     "GreenBuildVision"
#   ]
# }
# {
#   "description": "Innovative design studio merging architectural aesthetics, mechanical engineering, and environmental sustainability. Our team crafts functional, energy-efficient structures that seamlessly blend form and function, delivering a harmonious built environment for future generations.",
#   "names": [
#     "EcoFormArchitects",
#     "SustainableShapeDesign",
#     "GreenEngineeredSpaces",
#     "EcoFunctionDesigns",
#     "SustainableShapeSolutions"
#   ]
# }
# {
#   "description": "Introducing 'VisionaryBuild', a leading Architectural, Engineering, and Related Services firm dedicated to transforming spaces with innovative design and cutting-edge technology. Our team of experts specializes in structural engineering, interior design, and sustainable solutions, creating functional, beautiful, and eco-friendly structures tailored to our clients' unique needs and visions. From concept to completion, we prioritize collaboration, creativity, and excellence in every project.",
#   "names": [
#     "VisionaryDesignSolutions",
#     "TechnoArchitects",
#     "InnovativeBuildSolutions",
#     "EcoTechDesigns",
#     "CollaborativeBuild"
#   ]
# }
# {
#   "description": "Visionary Build: A renowned architectural firm offering integrated solutions in structural engineering, mechanical, electrical, and plumbing engineering, and interior design, delivering functional and inspiring spaces for modern living.",
#   "names": [
#     "IntegratedBuild",
#     "ArchitectureSynergy",
#     "MEPDesignPro",
#     "SpaceVisionaries",
#     "EngineeredLiving"
#   ]
# }
# {
#   "description": "Visionary Build: A premier architectural firm delivering cutting-edge design solutions in architecture, engineering, and interior design, merging functionality, sustainability, and artistry to create inspiring and innovative built environments.",
#   "names": [
#     "InnovArch",
#     "DesignSynergy",
#     "BuildVision",
#     "ArchEcoSys",
#     "CreativeConstruct"
#   ]
# }
# Industry: Architectural, Engineering, and Related Services, Valid JSON Count: 25, Total Attempts: 25
# Specialized Design Services
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our core services include graphic design, UX/UI design, and 3D modeling. We pride ourselves on delivering visually stunning, user-friendly, and engaging designs that captivate audiences and drive growth.",
#   "names": [
#     "PixelNarrative",
#     "DesignCrafters",
#     "VisualVoyagers",
#     "StorytellerDesign",
#     "CraftedPixels"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our expertise lies in graphic design, web design, and animation, crafting captivating brand experiences that resonate with audiences.",
#   "names": [
#     "PixelNarratives",
#     "BrandCrafters",
#     "DesignPioneers",
#     "VisualStorytellers",
#     "PixelStory"
#   ]
# }
# {
#   "description": "A creative design agency dedicated to crafting innovative and captivating visual solutions, providing graphic design, product design, and animation services, partnering with clients to breathe life into their ideas and transform them into engaging experiences.",
#   "names": [
#     "ideaventure",
#     "visualmagnet",
#     "creativeforge",
#     "designspark",
#     "innovisionary"
#   ]
# }
# {
#   "description": "Adept Designs: A pioneering design agency crafting innovative visual solutions, delivering top-tier graphic design, branding strategy, and 3D modeling services.",
#   "names": [
#     "InnoViz",
#     "CraftedCreative",
#     "Think3DDesign",
#     "BrandCrafters",
#     "VizWorx"
#   ]
# }
# {
#   "description": "Introducing PixelPinnacle, a creative design powerhouse specializing in innovative visual solutions. With a focus on graphic design, web design, and 3D modeling, we breathe life into your brand's digital presence, crafting captivating stories that engage and inspire.",
#   "names": [
#     "PixelNexus",
#     "DesignPeak",
#     "VisualVortex",
#     "CreativeCrest",
#     "PixelPinnacle"
#   ]
# }
# {
#   "description": "A creative design lab, mastering the art of visual storytelling through innovative graphic design, intuitive UX/UI solutions, and captivating 3D visualizations. We partner with businesses to breathe life into their brands and captivate audiences, crafting compelling narratives that resonate and inspire.",
#   "names": [
#     "NarrativeForge",
#     "BrandCrafters",
#     "VisualAlchemist",
#     "StorytellerWorks",
#     "DesignNarratives"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design studio dedicated to transforming businesses through innovative visual storytelling. Our team of experts weaves together graphic design, UX/UI design, and 3D animation magic to create captivating brand experiences that leave a lasting impression.",
#   "names": [
#     "PixelNarratives",
#     "BrandCrafters",
#     "VisualVoyagers",
#     "DesignPioneers",
#     "StorytellingPixels"
#   ]
# }
# {
#   "description": "A creative design lab, mastering the art of visual storytelling, providing bespoke graphic design, branding, and illustration services, crafting compelling narratives that resonate with audiences and elevate businesses.",
#   "names": [
#     "NarrativeArt",
#     "VisualCrafts",
#     "StorytellerDesign",
#     "IllustrativeNarratives",
#     "BrandNarratives"
#   ]
# }
# {
#   "description": "A creative sanctuary dedicated to transforming businesses through innovative architectural design, providing sustainable solutions, interior design consulting, and 3D rendering services, crafting spaces that inspire and invigorate.",
#   "names": [
#     "archidevise",
#     "spacecrafted",
#     "designbloom",
#     "innovatespace",
#     "architecturalnest"
#   ]
# }
# {
#   "description": "A creative design agency dedicated to crafting innovative and captivating experiences, specializing in graphic design, product design, and interactive media, partnering with clients to breathe life into their bold ideas and transform them into engaging realities.",
#   "names": [
#     "ideabloom",
#     "creativefusion",
#     "designalchemy",
#     "innovationforge",
#     "imaginativeleap"
#   ]
# }
# {
#   "description": "A pioneering design agency dedicated to crafting innovative and sustainable solutions, merging art and science through architectural design, 3D modeling, and virtual reality experiences.",
#   "names": [
#     "ArchVisionary",
#     "SustainableCreations",
#     "ArtScienceFusion",
#     "RealityCrafters",
#     "InnovationDesign"
#   ]
# }
# {
#   "description": "A creative sanctuary dedicated to transforming businesses through innovative and intuitive design solutions. Our team of experts weaves together graphic design, product design, and digital animation, crafting visually stunning and user-friendly experiences that captivate and inspire.",
#   "names": [
#     "DesignCrafted",
#     "InnovationForge",
#     "VisualAlchemy",
#     "DesignSynergy",
#     "CreativeFusion"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our expertise lies in graphic design, web design, and 3D modeling, crafting captivating brand experiences that resonate with audiences.",
#   "names": [
#     "PixelNarratives",
#     "BrandCrafters",
#     "VisualVoyagers",
#     "DesignPioneers",
#     "StorytellingPixels"
#   ]
# }
# {
#   "description": "Introducing PixelPinnacle, a creative design agency that elevates your brand's visual language through custom illustrations, animations, and interactive design. Our team of experts collaborates closely with clients to bring their unique stories to life, delivering engaging and memorable design solutions.",
#   "names": [
#     "PixelNarrative",
#     "StoryboardSavvy",
#     "BrandCraft",
#     "IllustrativeEdge",
#     "DesignElevate"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to crafting innovative visual solutions. Our expertise lies in graphic design, web design, and 3D modeling, all tailored to bring your brand to life and captivate your audience.",
#   "names": [
#     "PixelCrafts",
#     "BrandVoyage",
#     "DesignTrailblazers",
#     "PixelNexus",
#     "InnovativeVisuals"
#   ]
# }
# {
#   "description": "A creative sanctuary dedicated to transforming businesses through innovative and captivating design solutions. Our team of experts weaves together the art of graphic design, the science of UX/UI design, and the magic of 3D animation to craft compelling brand narratives that resonate with audiences and leave lasting impressions.",
#   "names": [
#     "NarrativeForge",
#     "BrandAlchemy",
#     "DesignCrafters",
#     "VisualNexus",
#     "StorytellersGuild"
#   ]
# }
# {
#   "description": "Adept Design House: Pioneering innovative design solutions, we weave together strategy, creativity, and technology to craft exceptional visual identities, user experiences, and interactive media.",
#   "names": [
#     "BrandCraft",
#     "DesignWeave",
#     "InnovationThread",
#     "CreativeFusion",
#     "StrategicPixel"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our expertise lies in graphic design, web design, and 3D product modeling, crafting captivating brand identities and user experiences.",
#   "names": [
#     "PixelNarrative",
#     "BrandCrafters",
#     "DesignPioneers",
#     "VisualVoyagers",
#     "CreativeCatalyst"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our expertise lies in graphic design, web design, and 3D modeling, crafting visually stunning and user-friendly solutions tailored to our clients' unique needs.",
#   "names": [
#     "PixelNarrative",
#     "DesignTrailblazers",
#     "VisualVoyagers",
#     "StorytellingPixels",
#     "InnovationCanvas"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design studio dedicated to transforming businesses through innovative visual storytelling. Our team of experts weaves together graphic design, branding strategy, and cutting-edge technology to create captivating digital experiences. From intricately designed logos to intuitively crafted websites and engaging multimedia content, PixelPioneers empowers brands to stand out in today's competitive marketplace.",
#   "names": [
#     "PixelNarratives",
#     "BrandCrafters",
#     "VisualVoyagers",
#     "DesignPioneers",
#     "StorytellingPixels"
#   ]
# }
# {
#   "description": "A creative sanctuary dedicated to transforming ordinary spaces into extraordinary ones, specializing in architectural and interior design, offering bespoke solutions for residential and commercial projects, blending art, function, and sustainability to craft unique environments.",
#   "names": [
#     "envisionbuild",
#     "artisanspace",
#     "architecturalalchemy",
#     "designharmony",
#     "creativeconstruct"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to transforming businesses through innovative visual storytelling. Our expertise lies in crafting captivating logos, designing intuitive websites, and developing engaging multimedia content.",
#   "names": [
#     "PixelNarrative",
#     "VisualVoyagers",
#     "StorytellerDesign",
#     "BrandCrafters",
#     "CreativePioneers"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a trailblazing design agency dedicated to crafting innovative visual solutions. Our expertise lies in graphic design, web design, and 3D modeling, all tailored to bring your brand to life and captivate your audience.",
#   "names": [
#     "PixelCrafters",
#     "BrandVisionaries",
#     "DesignCraftsmen",
#     "PixelNexus",
#     "CreativePixel"
#   ]
# }
# {
#   "description": "Introducing PixelPioneers, a creative powerhouse specializing in innovative visual solutions. With a focus on graphic design, web design, and 3D modeling, we bring your brand to life through captivating storytelling and visually stunning design.",
#   "names": [
#     "PixelNarrative",
#     "DesignCrafters",
#     "VisualVoyagers",
#     "BrandCraft",
#     "PixelStorytellers"
#   ]
# }
# {
#   "description": "Adept Designs: A creative powerhouse specializing in innovative architectural designs and 3D rendering services, bringing your structures to life with intricate detail and dynamic visuals.",
#   "names": [
#     "ArchVizPro",
#     "Design3DHub",
#     "BuildViz",
#     "ArchitecturalAesthetics",
#     "VizCraft"
#   ]
# }
# Industry: Specialized Design Services, Valid JSON Count: 25, Total Attempts: 25
# Scientific Research and Development Services
# {
#   "description": "MolecularMiracles: Transforming the world through innovative scientific research and development services, focusing on advanced genetics, biotechnology, and chemical engineering.",
#   "names": [
#     "DnaAlchemy",
#     "MolecularMavens",
#     "GeneticsGlory",
#     "BioChemBridge",
#     "InnovativeElements"
#   ]
# }
# {
#   "description": "Quantum Leap Labs: Pushing the boundaries of science with our advanced research and development services in robotics, artificial intelligence, and renewable energy. Our team of visionary scientists and engineers work closely with clients to transform ideas into reality, bringing future technologies to the present.",
#   "names": [
#     "FutureTech",
#     "InnovationForge",
#     "QuantumMakers",
#     "TechnoGenius",
#     "BrainTrustLabs"
#   ]
# }
# {
#   "description": "MolecularMiracles: At the heart of scientific discovery, we blend creativity and innovation to unlock the secrets of the universe. Our team of dedicated researchers and scientists work tirelessly in the fields of genetics, biochemistry, and physics to develop groundbreaking technologies and solutions. From curing diseases to creating sustainable energy, MolecularMiracles is dedicated to pushing the boundaries of scientific knowledge and improving the world.",
#   "names": [
#     "DNAwonders",
#     "ElementalInnovations",
#     "MolecularMakers",
#     "QuantumLeapSci",
#     "NanochemLab"
#   ]
# }
# {
#   "description": "MolecularMiracle: At the heart of scientific discovery, we combine the power of nature and innovation to create groundbreaking solutions. Our team of dedicated researchers and scientists explore the depths of biochemistry, genetics, and physics to unravel the mysteries of the universe. With a focus on sustainability and ethical practices, we deliver transformative technologies in fields such as agriculture, environmental science, and medicine.",
#   "names": [
#     "BioAlchemyLab",
#     "MolecularMystic",
#     "GenesisScience",
#     "ElementalInnovate",
#     "NatureNexusLab"
#   ]
# }
# {
#   "description": "MolecularMiracles: At the heart of scientific discovery and innovation, MolecularMiracles pushes the boundaries of research and development in the fields of biotechnology, chemistry, and physics. Our team of passionate and curious scientists and engineers collaborate on groundbreaking projects, transforming ideas into reality for industries such as healthcare, agriculture, and renewable energy. With a commitment to sustainability and ethical practices, MolecularMiracles is dedicated to creating a better future through science.",
#   "names": [
#     "DiscoverySpark",
#     "ScienceSynergy",
#     "MiracleMolecules",
#     "InnovationNexus",
#     "ElementalEvolution"
#   ]
# }
# {
#   "description": "Quantum Leap Research: Propelling industries forward with advanced scientific research and development services in robotics, AI, and renewable energy. Our team of visionary scientists and engineers partner with clients to revolutionize their businesses, transforming ideas into reality and shaping the future.",
#   "names": [
#     "FutureForge",
#     "Innoventia",
#     "TechnoGenesis",
#     "ProgressionLabs",
#     "QuantumMakers"
#   ]
# }
# {
#   "description": "Quantum Leap Research: Propelling businesses forward with advanced scientific research and development services in robotics, AI, and renewable energy. Our team of visionary scientists and engineers work hand-in-hand with clients to transform ideas into commercially viable solutions, bridging the gap between innovation and implementation.",
#   "names": [
#     "ScienceSpark",
#     "TechNexusLabs",
#     "InnovationForge",
#     "QuantumInvent",
#     "BrainTrustScience"
#   ]
# }
# {
#   "description": "MolecularMiracle: At the heart of scientific discovery, we combine the power of nature and innovation to create groundbreaking solutions. Our team of dedicated researchers and scientists work tirelessly in the fields of genetics, biochemistry, and bioengineering to develop new technologies and products. From pharmaceuticals to agriculture, our discoveries are shaping the future of health and sustainability.",
#   "names": [
#     "BioInnovate",
#     "GeneSynth",
#     "MoleculeMakers",
#     "DiscoveryDNA",
#     "GenesisGenetics"
#   ]
# }
# {
#   "description": "MolecularMiracles: Transforming the world through innovative scientific research and development services, focusing on advanced molecular biology, genetic engineering, and drug discovery.",
#   "names": [
#     "GeneWonders",
#     "MoleculeMavens",
#     "BioDesignBrilliance",
#     "DNAInnovations",
#     "MolecularMastery"
#   ]
# }
# {
#   "description": "Quantum Leap Research: Pushing the boundaries of scientific discovery with our innovative research and development services in fields such as robotics, artificial intelligence, and advanced materials. Our team of brilliant scientists and engineers work closely with clients to transform ideas into reality, bringing future technologies to the present.",
#   "names": [
#     "Futuritech",
#     "BrightSparkLabs",
#     "InnovationForge",
#     "QuantumMakers",
#     "AdvancedAlchemy"
#   ]
# }
# {
#   "description": "Quantum Leap Labs: Pushing the boundaries of scientific discovery with our innovative research and development services in fields such as robotics, artificial intelligence, and advanced materials. Our team of brilliant scientists and engineers work closely with clients to transform ideas into reality, bringing future technologies to the present.",
#   "names": [
#     "FutureForge",
#     "InnoTechFusion",
#     "BrightSparkLabs",
#     "NextGenScience",
#     "AdvancementArchitects"
# ...
#   "names": [
#     "SacredSanctuary",
#     "HeavenlyHelp",
#     "SpiritualSynergy",
#     "CaringCompass",
#     "FaithfulFulcrum"
#   ]
# }
# {
#   "description": "CompassionateCare: A faith-based organization offering spiritual guidance, community development projects, and humanitarian aid.",
#   "names": [
#     "FaithfulFund",
#     "HopeHub",
#     "CharityChapel",
#     "CompassionCrest",
#     "BlessedBeginnings"
#   ]
# }
#
# This business, CompassionateCare, is a faith-based organization that provides a variety of services to help uplift individuals and communities. They offer spiritual guidance through prayer, meditation, and counseling. In addition, they engage in community development projects, such as building schools, hospitals, and homes for those in need. Lastly, they provide humanitarian aid in the form of food, clothing, and other essentials to those affected by poverty, natural disasters, or conflict. The name suggestions reflect the core services of spiritual guidance
# {
#   "description": "DivineCare: A faith-based organization offering spiritual guidance, charitable services, and community outreach programs for the underprivileged and marginalized.",
#   "names": [
#     "FaithfulAid",
#     "HeavenlyHelp",
#     "BlessedBridge",
#     "AngelicAssistance",
#     "HopeHaven"
#   ]
# }
#
# This business, named DivineCare, is dedicated to providing spiritual guidance and charitable services to those in need. Our team of compassionate and trained professionals offers spiritual counseling, crisis intervention, and community outreach programs tailored to the unique needs of the underprivileged and marginalized individuals. Through our faith-based approach, we aim to foster hope, healing, and a sense of belonging among those we serve. Our goal is to create a supportive and inclusive environment where individuals can find comfort,
# {
#   "description": "DivineCompassion: A faith-based organization offering spiritual guidance, community support groups, and humanitarian aid services.",
#   "names": [
#     "FaithfulAid",
#     "HealingHandsOfGod",
#     "DivineSupport",
#     "SpiritualSafeguard",
#     "CompassionateCrusade"
#   ]
# }
# Industry: Religious (except Schools) and Welfare Activities, Valid JSON Count: 25, Total Attempts: 29
# Gambling Industries.
# {
#   "description": "RouletteRush: Your adrenaline-pumping virtual casino, where the spin of the wheel determines your fortune. Specializing in an extensive collection of online roulette games, with various table limits and live dealer experiences to bring the thrill of the casino to you.",
#   "names": [
#     "WheelFortune",
#     "RushRoulette",
#     "SpinCasino",
#     "RouletteRevolution",
#     "FortuneSpinner"
#   ]
# }
# {
#   "description": "RouletteRush: Experience the thrill of the spin at our premier online gambling destination. Offering an extensive collection of virtual roulette tables, live dealer games, and daily promotions, all designed to deliver an authentic and exhilarating casino experience right at your fingertips.",
#   "names": [
#     "RouletteRevolution",
#     "SpinCentral",
#     "WheelFortune",
#     "RushGames",
#     "LuckyWheel"
#   ]
# }
# {
#   "description": "RouletteRush: Your adrenaline-pumping virtual gambling destination, where the spin of the wheel determines your fortune. Offering an immersive experience with a vast selection of online roulette games, live dealer roulette, and exclusive promotions to keep the thrill alive.",
#   "names": [
#     "WheelFortune",
#     "RushRoulette",
#     "SpinKingdom",
#     "RouletteRevolution",
#     "FortuneSpin"
#   ]
# }
# {
#   "description": "StakeAndStrategize: Your premier online gaming destination where skill meets luck. Our platform offers a vast collection of casino games, sports betting, and poker rooms. With cutting-edge technology, players can enjoy live dealer games, real-time statistics, and customizable interfaces. Our secure and user-friendly website ensures a seamless gaming experience. Join our community of strategists and compete in tournaments for exclusive rewards.",
#   "names": [
#     "GameSavvy",
#     "StrategicBet",
#     "SkillStakes",
#     "LuckyWagers",
#     "BetBrain"
#   ]
# }
# {
#   "description": "Mystic Riches: An enchanting online gambling destination where fortune favors the bold. Immerse yourself in a magical world of endless entertainment with our wide range of virtual casino games, including poker, blackjack, roulette, and slots. Our advanced security measures ensure a secure and fair gaming experience for all our valued customers.",
#   "names": [
#     "enchantedgamble",
#     "mysticbet",
#     "richescasino",
#     "charmingwinnings",
#     "fortunegames"
#   ]
# }
# {
#   "description": "Mystic Fortune: A captivating online gambling destination where ancient magic meets modern technology. Embark on a thrilling journey through our enchanted casino, featuring a wide array of spellbinding slot games, table magic, and a mystical VIP realm. Our advanced security ensures a secure and enchanted environment for all our valued customers.",
#   "names": [
#     "enchantedgames",
#     "mysticbet",
#     "spellcasino",
#     "fortunemagic",
#     "wizardrolls"
#   ]
# }
# {
#   "description": "Mystic Fortune: A captivating online gambling destination where magic and luck come together. Our platform offers an extensive collection of enchanted slots, table games, and live dealer experiences, all infused with a mystical ambiance. Secure and trusted, Mystic Fortune promises an immersive and thrilling journey for every player.",
#   "names": [
#     "enchantedgames",
#     "mysticbet",
#     "fortunepalace",
#     "spellbindingcasino",
#     "wizardslots"
#   ]
# }
# {
#   "description": "Vegas Nights: Immerse yourself in the thrilling world of chance with Vegas Nights - the ultimate virtual gambling destination. Our platform offers a wide range of games including poker, blackjack, roulette, and slot machines, all designed to deliver an authentic and exciting experience. Our advanced security measures ensure fair play and data protection, making every visit to Vegas Nights a safe and enjoyable one.",
#   "names": [
#     "chancepalace",
#     "gambler'sguild",
#     "rollersparadise",
#     "luckylounge",
#     "casinoclubhouse"
#   ]
# }
# {
#   "description": "Vegas Nights: Immerse yourself in an exhilarating world of chance with Vegas Nights, the ultimate online gambling destination. Our platform offers a diverse range of games, from classic table games to thrilling slot machines, all designed to deliver an authentic casino experience. With top-tier security measures and a user-friendly interface, Vegas Nights ensures a safe, fair, and enjoyable gaming journey for all.",
#   "names": [
#     "casinoburst",
#     "gametableau",
#     "luckydice",
#     "rollersparadise",
#     "vegasvortex"
#   ]
# }
# {
#   "description": "Vegas Nights: Immerse yourself in the thrilling world of chance with Vegas Nights, the ultimate virtual casino experience. Our platform offers a wide range of games including poker, blackjack, roulette, and slots, all designed to deliver an authentic and exciting gambling adventure. With top-notch security measures and a user-friendly interface, Vegas Nights ensures a fair, safe, and enjoyable gaming environment for all.",
#   "names": [
#     "casinoblitz",
#     "vegasvibes",
#     "gamblersparadise",
#     "rouletterevolution",
#     "slotsnirvana"
#   ]
# }
# {
#   "description": "RouletteRush: Your adrenaline-pumping virtual gaming destination, where the spin of the wheel determines your fortune. Specializing in an extensive collection of online roulette games, with various table limits and live dealer experiences to bring the thrill of the casino right to your screen.",
#   "names": [
#     "WheelFortune",
#     "RushCasino",
#     "RouletteRevolution",
#     "SpinCentral",
#     "FortuneWheel"
#   ]
# }
# {
#   "description": "RouletteRush: Your adrenaline-pumping virtual gaming destination, where the spin of the wheel determines your fortune. Specializing in an extensive collection of online roulette games, with various table limits and live dealer experiences to bring the thrill of the casino to you.",
#   "names": [
#     "WheelFortune",
#     "RushGaming",
#     "RouletteRevolution",
#     "SpinCentral",
#     "FortuneSpinner"
#   ]
# }
# {
#   "description": "RouletteRush: Your adrenaline-pumping virtual gambling destination, where the thrill of the spin never fades. Specializing in an extensive variety of online roulette games, including European, American, and French versions, as well as live dealer experiences and daily promotions to amplify the excitement and increase your chances of winning.",
#   "names": [
#     "RouletteRevolution",
#     "SpinSensation",
#     "WheelWealth",
#     "RouletteRewards",
#     "FortuneSpinner"
#   ]
# }
# {
#   "description": "Mystic Riches: A captivating online gambling platform where fortune's favorites come together to revel in an immersive gaming experience. Our extensive collection of enchanted slots, skill-testing table games, and live dealer rooms are all backed by our commitment to fairness and security.",
#   "names": [
#     "mysticriches",
#     "enchantedgames",
#     "fortunesfavor",
#     "charmingcasino",
#     "mythicalwinnings"
#   ]
# }
# {
#   "description": "Mystic Riches: A captivating online gambling destination where fortune's favorites come together to revel in the thrill of chance. Our extensive library of games, from classic table games to cutting-edge slots, is complemented by our commitment to providing a secure and immersive experience. Join us and let the magic of Mystic Riches transform your luck.",
#   "names": [
#     "enchantedgames",
#     "fortunesparks",
#     "mysticwinnings",
#     "richesroulette",
#     "charmingcasino"
#   ]
# }
# {
#   "description": "StellarSpins Casino: A celestial-themed gaming paradise where luck and excitement collide. Our expansive virtual casino floor features an array of slot games, table games, and live dealer options, all accessible from the comfort of your own home. Our cutting-edge technology and intuitive interface ensure a seamless and immersive gaming experience. Join our cosmic community for special promotions, rewards, and exclusive access to new games. Prepare for a galactic adventure filled with fun and potential winnings.",
#   "names": [
#     "CosmoCasino",
#     "GalacticGames",
#     "StarSpins",
#     "CelestialChance",
#     "AstroBet"
#   ]
# }
# {
#   "description": "StakeAndLuck: Your premier online gambling destination, where luck and strategy meet. Offering a vast selection of casino games, including poker, blackjack, roulette, and slots, our platform is designed for both novice and experienced players. Our user-friendly interface, generous bonuses, and top-notch security make StakeAndLuck the go-to choice for online gambling enthusiasts. Join our community of players and enjoy the thrill of the game from the comfort of your own home.",
#   "names": [
#     "GambleHub",
#     "LuckPit",
#     "StakeSphere",
#     "RollerRing",
#     "CardCasino"
#   ]
# }
# {
#   "description": "StakeAndStrategize: Your premier online gaming destination for strategic thinkers and risk-takers alike. Our platform offers a vast selection of casino games, sports betting, and skill-based competitions. With advanced analytics tools and real-time data, you can make informed decisions and maximize your winnings. Experience seamless gameplay on desktop and mobile devices, and enjoy secure transactions and top-notch customer support.",
#   "names": [
#     "StrategicGames",
#     "AnalyticBet",
#     "SmartStakes",
#     "DataDice",
#     "IntellectGamble"
#   ]
# }
# {
#   "description": "StellarBet: A celestial gaming paradise where luck and skill collide. Our virtual casino offers an extensive collection of games, from classic table games and slots to cutting-edge virtual sports and live dealer options. Our user-friendly platform is accessible on desktop and mobile devices, ensuring a seamless gaming experience. Join our community of players and take part in thrilling tournaments, daily promotions, and loyalty rewards.",
#   "names": [
#     "GalaxyGames",
#     "CosmicCasino",
#     "StarSpins",
#     "AstroBetting",
#     "PlanetPot"
#   ]
# }
# {
#   "description": "Mystic Riches Emporium: A captivating virtual gambling hall, where ancient magic meets modern technology. Delve into an enchanted world of fortune-telling slot machines, table games guarded by mythical creatures, and a mystical VIP lounge. Our advanced security ensures a secure and fair gaming environment for all our valued patrons.",
#   "names": [
#     "enchantedgamble",
#     "mysticbet",
#     "fortunespinner",
#     "mythiccasino",
#     "mysticrolls"
#   ]
# }
#
# Or, if the business name is "Lucky Paws Casino":
#
# {
#   "description": "Lucky Paws Casino: A whimsical online gambling destination where fun and fortune await. Play a paw-some selection of games, from classic table games and slot machines to unique
# {
#   "description": "Mystic Fortune: An enchanting virtual casino where luck and magic intertwine, offering an extensive collection of table games, slots, and live dealer experiences. Our cutting-edge technology and dedicated customer support ensure a captivating and secure gaming journey for all our valued members.",
#   "names": [
#     "fortunemystic",
#     "enchantedgames",
#     "mysticreels",
#     "spellboundcasino",
#     "luckysorcerer"
#   ]
# }
# {
#   "description": "RouletteRush: Your adrenaline-pumping online gambling destination, where the spin of the wheel determines your fortune. Offering an exhilarating variety of roulette games, live dealer experiences, and daily bonuses to keep the thrill alive for every player.",
#   "names": [
#     "WheelFortune",
#     "RushGambling",
#     "RouletteRevolution",
#     "SpinAndWin",
#     "FortuneSpinner"
#   ]
# }
# {
#   "description": "StakeAndStrategize: Your premier online gambling destination for strategic minds and lucky hearts. Discover a vast collection of casino games, including poker, blackjack, roulette, and slots. Our platform is designed with cutting-edge technology, ensuring a seamless and secure gaming experience. Join our community of players, engage in live tournaments, and benefit from expert tips and strategies. Unlock exclusive rewards and bonuses through our loyalty program.",
#   "names": [
#     "StrategicGames",
#     "CasinoMastermind",
#     "PokerPulse",
#     "LuckyLeverage",
#     "GambleGenius"
#   ]
# }
# {
#   "description": "Vegas Nights: Immerse yourself in the thrilling world of chance with Vegas Nights - a premier online gambling destination. Our platform offers an extensive collection of casino games, from classic table games to cutting-edge slots, all designed to deliver an authentic and exhilarating experience. Our commitment to security and fairness ensures peace of mind for all our players, making Vegas Nights the ultimate virtual casino.",
#   "names": [
#     "casinoblitz",
#     "vegasvortex",
#     "gamblersparadise",
#     "slotsof fortune",
#     "rouletterevolution"
#   ]
# }
# {
#   "description": "RouletteRush: Experience the thrill of the spin with our immersive online casino. Discover a vast selection of roulette games, blackjack tables, poker rooms, and daily tournaments, all designed to deliver excitement and potential wins to every player. Join our community of enthusiasts and let the good times roll!",
#   "names": [
#     "RouletteRevolution",
#     "SpinCasino",
#     "TableThrills",
#     "JackpotJunction",
#     "DealerDen"
#   ]
# }
# {
#   "description": "StakeAndStrategize: Your premier online gambling destination for strategic minds and lucky hearts. Our platform offers a vast selection of games, from classic table games like blackjack and poker, to thrilling slot machines and live dealer options. Our advanced analytics tools help you make informed decisions, while our secure and fair gaming environment ensures a fun and trustworthy experience. Join our community of players and strategists, and take your gambling game to the next level.",
#   "names": [
#     "StrategicGamble",
#     "AnalyticBet",
#     "SmartWager",
#     "DataDealer",
#     "InsightSpins"
#   ]
# }
# Industry: Gambling Industries., Valid JSON Count: 25, Total Attempts: 26

# %%
# Check used tokens
total_prompt_tokens = sum(response.usage.prompt_tokens for response in all_raw)
total_completion_tokens = sum(response.usage.completion_tokens for response in all_raw)

print(f"Total prompt tokens: {total_prompt_tokens}")
print(f"Total completion tokens: {total_completion_tokens}")
# Out:
# Total prompt tokens: 641974
# Total completion tokens: 373747

# %%
# filter only valid data
data = [result for result in all_results if result['JSON'] == "YES"]

len(data)
# Out:
# 5000

# %%
# create train/test split. Make sure to keep industry distribution even

from collections import defaultdict
import math

# Transform the list of dictionaries
transformed_data = []
for item in data:
    transformed_item = {
        'prompt': item['response']['description'],
        'response': [name.lower() for name in item['response']['names']], # make sure all names are lowercase
        'industry': item['response']['industry']
    }
    transformed_data.append(transformed_item)

# Group data by industry
industry_groups = defaultdict(list)
for item in transformed_data:
    industry_groups[item['industry']].append(item)

# Initialize train and test sets
train_data = []
test_data = []

# Split proportion
split_proportion = 0.7  # 70% train, 30% test

# Stratify split by industry
for industry, items in industry_groups.items():
    split_index = math.floor(len(items) * split_proportion)
    train_data.extend(items[:split_index])
    test_data.extend(items[split_index:])

# Output the structure and some statistics about the datasets
print(f"Training dataset: {len(train_data)} rows")
print(f"Testing dataset: {len(test_data)} rows")
# Out:
# Training dataset: 3427 rows
# Testing dataset: 1573 rows

# %%
# Write datasets to a JSON file

json_file_path = 'train_dict.json'
with open(json_file_path, 'w') as file:
    json.dump(train_data, file)

print(f"Dataset dictionary has been written to {json_file_path}.")

json_file_path = 'test_dict.json'
with open(json_file_path, 'w') as file:
    json.dump(test_data, file)

print(f"Dataset dictionary has been written to {json_file_path}.")
# Out:
# Dataset dictionary has been written to train_dict.json.
# Dataset dictionary has been written to test_dict.json.

# %% [markdown]
# # Validation dataset creation

# %% [markdown]
# To make sure business descriptions are diffrent than in test and training datasets for this task I am using Mixtral 8x7B model
#
# Also these descriptions will be of different format which might be closer to what domain team will have.

# %%
# Set model
model = "open-mixtral-8x7b"

# Initialize storage for results
all_descriptions = []
all_descriptions_raw = []

num_queries = round(500/len(industries))    # Number of times to run query for each industry

# Base prompt template with placeholders for examples and industry
base_prompt_template = """
Generate a short and creative business description for a company in the {industry} industry.

"""

# %%
# Validation dataset generation

# Iterate through each industry
for industry in industries:
    print(industry)  # For debugging

    for _ in range(num_queries):  # Run until valid JSON responses reach num_queries

        # Update content for each query to include the new example
        content = base_prompt_template.format(industry=industry)
        messages = [ChatMessage(role="user", content=content)]

        chat_response = client.chat(model=model,
                                    messages=messages,
                                    max_tokens=200,
                                    temperature=0.7)

        # Store the raw chat response content
        response_content = chat_response.choices[0].message.content if chat_response.choices else "No response"
        print(response_content)

        all_descriptions.append(response_content)  # Add the result record to the all_results list
        all_descriptions_raw.append(chat_response)
# Out:
# Used Merchandise Stores
# "Revive Treasures: Unearthing Pre-loved Gems! We breathe new life into yesteryear's treasures, offering a vibrant collection of used merchandise that's been thoughtfully curated and sustainably sourced. From vintage fashion finds to pre-owned home décor, every item at Revive Treasures tells a story waiting to be discovered. Join us in our mission to reduce waste, promote circular economy, and celebrate the charm of the past. Your next favorite piece is just a thrift store adventure away!"
# "Revive Treasures: Unleashing the Hidden Gems of Yesteryears! We handpick, polish, and present preloved merchandise, transforming forgotten treasures into your unique statement pieces. With a twist of nostalgia and a dash of sustainability, Revive Treasures invites you to explore, reimagine, and celebrate the charm of the past, today!"
# "At Revive Treasures, we believe that one person's trash is another's treasure! As your friendly neighborhood used merchandise store, we handpick every item on our shelves to ensure you find nothing but unique, high-quality, and affordable pre-loved goods. From vintage clothing and timeworn trinkets to nearly-new electronics and home decor, our ever-changing inventory is a treasure trove waiting to be explored. Revive Treasures - where your pre-loved dreams come true!"
# Information Services
# "DataSage: Unlocking the Hidden Potential of Your Information!
#
# At DataSage, we believe that information is the lifeblood of the modern organization. That's why we've made it our mission to help businesses unlock the hidden potential of their data, transforming raw numbers into actionable insights that drive growth, innovation, and success.
#
# Our team of data scientists, analysts, and engineers use the latest tools and techniques to collect, clean, and analyze your data, uncovering patterns and trends that might otherwise go unnoticed. Whether you're looking to improve customer engagement, optimize supply chain operations, or identify new market opportunities, we have the expertise and experience to help you achieve your goals.
#
# But we don't just stop at analysis. We also provide comprehensive information services, including data visualization, reporting, and dashboard creation, so you can easily share your insights with stakeholders and decision-makers
# "DataSprout: Cultivating Insights from the Digital Garden
#
# At DataSprout, we don't just collect data, we cultivate it. We believe in nurturing the raw information from the digital landscape, weeding out the irrelevant, and pruning it into actionable insights. Our innovative solutions empower businesses to grow and flourish in the modern world. With DataSprout, you're not just getting data, you're getting a thriving information ecosystem."
# "DataSprout: Cultivating Insights from the Digital Garden! We are a dynamic Information Services company, specializing in data harvesting, pruning, and transformation. Our team of seasoned analysts and data scientists sift through the noise of the digital world, unearthing actionable insights that empower businesses to make informed decisions and thrive in an ever-changing landscape. With DataSprout, watch your organization bloom!"
# Agriculture, Forestry, Fishing and Hunting
# "Seedling Sprouts: Nurturing Nature's Bounty! We are a passionate group of agricultural innovators, dedicated to cultivating sustainable practices in the realms of farming, forestry, fishing, and hunting. Our mission? To empower communities in harmonious coexistence with our planet, one seedling, tree, fish, and fowl at a time. Join us in growing a brighter, greener, and more delectable future, where the Earth's resources are respected and its creatures flourish."
# "Seedling Sprouts: Cultivating Nature's Bounty"
#
# At Seedling Sprouts, we're not just sowing seeds, we're nurturing relationships with the earth and our community. Our mission is to provide sustainable, organic produce that connects people back to the land. From our lush forestry projects to our thriving aquatic farms, we harvest biodiversity and flavor in every bite. Seedling Sprouts - where agriculture meets artisan craftsmanship for a taste of nature's finest.
# "Seedling Sprouts: Cultivating Sustainable Futures"
#
# At Seedling Sprouts, we're not just growing crops; we're nurturing a sustainable future. Specializing in Agriculture, Forestry, Fishing, and Hunting, we're dedicated to responsible resource management and eco-conscious farming practices. From our carefully tended fields to our thriving forests, we cultivate biodiversity while producing top-quality, organic produce, timber, and wild-caught seafood. Join us in savoring the fruits of our labor and contributing to a healthier planet.
# Rail Transportation
# "RailTrend Innovations: Pioneering the Future of Rail Transportation! We're not just moving cargo, we're charting new horizons. Our cutting-edge technology and sustainable practices redefine rail travel, ensuring safe, swift, and eco-friendly transportation solutions. Hop on the green revolution with us!"
# "RailTrend Innovations: Pioneering the Future of Rail Transportation! We're not just moving cargo, we're charting new horizons. Our cutting-edge technology and sustainable practices are redefining rail transportation, making it faster, safer, and more efficient. With us, every journey is an exciting leap towards a greener tomorrow."
# "RailTrend Innovations: Pioneering the Future of Rail Transportation! We're not just moving cargo, we're charting new horizons. Our cutting-edge rail solutions, powered by green technology, redefine efficiency and sustainability in logistics. Experience the seamless blend of speed, safety, and eco-friendly transportation with RailTrend Innovations."
# Outdoor Advertising
# "Billboards & Beyond: Crafting unforgettable first impressions in the great outdoors. We are the visionary storytellers of the open air, turning blank spaces into bold canvases that spark curiosity, engage audiences, and amplify brand voices across the globe. Our innovative outdoor advertising solutions breathe life into campaigns, forging connections with consumers on the move and creating lasting impressions in the uncluttered landscape of the open world."
# "At VistaWall, we don't just create billboards, we craft captivating conversations with the world outside. Our outdoor advertising solutions are not mere canvas on concrete jungles, but vibrant storytellers that engage, inspire, and connect. We transform urban landscapes into dynamic art galleries, making every commute an immersive journey and every cityscape a memorable vista. With VistaWall, your brand is not just seen, it's experienced."
# "At VistaWall, we don't just create billboards, we craft unforgettable landscapes of imagination. Our outdoor advertising solutions are a canvas for your brand's story, boldly painting it across the cityscape to captivate audiences and leave a lasting imprint. With us, every walk down the street becomes an art gallery stroll, every highway journey a cinematic experience - all powered by strategic insights and cutting-edge technology."
# Apparel Knitting Mills
# "Stitching Dreams: Your Canvas for Comfort & Style"
#
# At Stitching Dreams, we don't just weave threads into fabric - we paint dreams into reality. As a leading innovator in the Apparel Knitting Mills industry, we transform raw yarns into masterpieces that hug your body with comfort and drape you in style. Our commitment to quality, sustainability, and cutting-edge technology sets us apart as we create knitted apparel that resonates with both individuality and global trends. With every stitch, we aim to empower our customers to express themselves, making Stitching Dreams not just a clothing brand, but a lifestyle choice.
# "StitchWise: Where Tradition Meets Technology"
#
# At StitchWise, we artfully weave together tradition and innovation to create high-quality knitted apparel. Our state-of-the-art knitting mill, run by a team of seasoned textile artisans, produces stylish and comfortable garments that stand the test of time. With a keen eye for detail and a commitment to sustainability, we knit together comfort, fashion, and environmental responsibility, one stitch at a time.
# "Stitching Dreams: where every thread tells a story of comfort, style, and sustainability. We're not just knitting clothes, we're weaving warmth, personality, and eco-consciousness into each garment. Our Apparel Knitting Mills are the looms of love, crafting wardrobe heroes that speak to your soul and tread lightly on Mother Earth."
# Shoe Stores
# "Step into a world of comfort and style with our innovative shoe boutique, 'Sole Savvy.' At Sole Savvy, we believe that every step you take is a statement, and we're here to help you make it a bold one. Our handpicked collection of artisanal shoes, sourced from around the globe, caters to the fashion-forward, the comfort-seekers, and everyone in between. From sky-high stilettos to cloud-like sneakers, we've got a sole for every soul. Experience the perfect blend of fashion, function, and flair, and let your soles do the talking at Sole Savvy."
# "Step into a world of comfort and style with our innovative shoe boutique, 'Sole Savvy.' At Sole Savvy, we believe that every step you take is a statement, and we're here to help you make it a bold one. Our curated collection of footwear, from chic heels to functional sneakers, is handpicked to ensure the perfect blend of fashion, functionality, and fit. Our team of 'Sole Seekers' are dedicated to helping you find the perfect pair, whether you're climbing career ladders or conquering mountain trails. At Sole Savvy, we don't just sell shoes, we sell confidence, one step at a time."
# "Step into a world of comfort and style with our boutique shoe store, where every footstep is a fashion statement. At Sole Savvy, we curate a chic and cozy selection of shoes for the modern-day strider, ensuring that every pair is not only a perfect fit for your feet but also a statement piece for your wardrobe. Our experienced staff brings a wealth of footwear knowledge, helping you navigate through our eco-friendly and orthopedic-friendly collections, making us the go-to destination for trendsetters and health-conscious shoe enthusiasts alike. Come experience the blend of artisanal craftsmanship, contemporary design, and exceptional customer service that sets Sole Savvy apart in the Shoe Stores industry."
# Building Material and Garden Equipment and Supplies Dealers
# "Seed to Sky Homes: where we cultivate your dream living space! Our eco-conscious garden equipment and top-quality building materials empower both green thumbs and building buffs to create their own vibrant, sustainable oasis. From foundation to flourishing foliage, we're your one-stop shop for elevating your lifestyle, one brick and bloom at a time."
# "Seed to Sky Homes: where your backyard dreams take root! We're not just a building materials supplier; we're your partner in transforming house to home. From foundation formwork to rooftop solar panels, our eco-conscious, innovative solutions empower you to build, grow, and flourish. Plus, our garden equipment and supplies range from budding beginnings to blooming brilliance, ensuring your outdoor oasis is the envy of the neighborhood. Start your journey to a sustainable, stylish, and truly unique living space with Seed to Sky Homes."
# "Seed to Sky Homes: where innovation meets nature. We are your one-stop-shop for all building materials and garden supplies, providing eco-friendly solutions and cutting-edge technology to help you create the sustainable home of your dreams. From energy-efficient insulation to vertical garden kits, we've got you covered. With Seed to Sky Homes, not only will you build a better home, but you'll also contribute to a greener planet."
# Support Activities for Mining
# "Minebright: Igniting Mineral Magic! We're the spark that fuels the mining industry, providing specialized support services that illuminate hidden potential. From geological surveys and drilling solutions to environmental management and operational logistics, our brilliant team of experts turns your mining venture into a dazzling success story."
# "Minebright: Igniting Mineral Magic! We are the alchemists of the Support Activities for Mining industry, transforming the mundane into the magnificent. With our innovative solutions, we illuminate the path to greater efficiency, safety, and sustainability in mining operations. From drilling to blasting, excavating to processing, we're the spark that keeps the mining world aglow. Trust Minebright to brighten your mining journey!"
# "Mine Tech Ascendants: Propelling Mineral Extraction to New Heights! We are the dynamic force behind your mining success, providing cutting-edge technology, innovative solutions, and unparalleled expertise in support activities. From exploration and geological surveying to mine closure, we empower your operations, maximize efficiency, and ensure environmental stewardliness, all while unlocking the treasures of our planet in a safe, sustainable manner."
# Sporting Goods, Hobby, Book and Music Stores
# "Peak Passion Sports & Beyond: Unleashing your inner athlete, hobbyist, bookworm, and music enthusiast in one vibrant hub! From cutting-edge sporting gear to immersive hobbies, best-selling literature to soul-stirring melodies, we curate experiences that inspire, invigorate, and ignite the fire within. Join us on this thrilling journey, where passion knows no limits!"
# "Rev up your active lifestyle with Zipzoom Gear! Our store is a one-stop-shop for sports enthusiasts, hobbyists, bookworms, and music lovers. From high-performance athletic equipment to the latest page-turning bestsellers, hard-to-find musical instruments, and unique collectibles, we've got you covered. At Zipzoom Gear, we're not just selling products; we're fueling your passion for an active, inspired lifestyle. Come visit us today and let's get moving!"
# "Peak Pursuits: Igniting Passions, One Adventure at a Time! Your one-stop-shop for all things sporty, hobby-worthy, and brain-boosting. From high-performance athletic gear to captivating books, soulful music, and engaging hobbies, we curate experiences that inspire, motivate, and bring joy to every customer. At Peak Pursuits, we believe in fueling curiosity, cultivating creativity, and empowering individuals to reach new heights in their favorite pastimes."
# Building Construction
# "BrickCraft: Building Today for a Stronger Tomorrow! We are not just constructors, we are architects of your vision. Our team of skilled artisans and engineers transforms blueprints into breathtaking realities, crafting solid foundations for businesses to thrive and homes to flourish. At BrickCraft, we don't just build structures; we sculpt dreams into existence."
# "Brick by Brilliant Brick, we're not just constructing buildings, we're crafting enduring legacies. Our chiseled expertise and unyielding commitment to quality transform blueprints into breathtaking symphonies of steel, stone, and glass. At our core, we believe in building dreams, one brick at a time."
# "Brick & Beam is a trailblazing force in the building construction industry, crafting architectural masterpieces that stand the test of time. Our seasoned team of artisans, engineers, and visionaries collaborate to transform skylines and communities, blending innovative design with sustainable materials and time-honored craftsmanship. With us, every blueprint tells a story of enduring quality, environmental stewardship, and unparalleled artistry."
# Landscape Architectural Services
# "Green Spaces, Inspired Places: We are a Landscape Architectural Services company that transforms ordinary outdoor spaces into breathtaking, functional landscapes. Our team of innovative designers and horticulturists collaborate to create unique, eco-friendly environments that reflect your style and enhance the natural beauty of your surroundings. From urban rooftop gardens to serene residential retreats, we shape sustainable spaces where communities come together and individuals find peace. Let us craft your landscape story, where every detail tells a tale of beauty, balance and harmony with nature."
# "Green Visions Designs: Crafting Harmonious Outdoor Spaces. We are a team of creative landscape architects, transforming ordinary landscapes into breathtaking, eco-friendly havens. Our designs blend art, science, and nature to create unique outdoor experiences that nurture the body, mind, and soul. Let us help you reimagine your world, one landscape at a time."
# "Green Spaces, Inspired Places: Transforming outdoor environments into breathtaking, functional landscapes is our passion. At 'Bloom & Balance,' we weave art and science into every project, creating verdant sanctuaries that harmonize with nature and enhance the quality of life. Our team of innovative landscape architects delights in shaping sustainable spaces where communities gather, businesses thrive, and memories are made."
# Employment Services
# "JobJoy: Your Personal Talent Navigator! We don't just find you a job, we chart a career course that aligns with your skills, passions, and aspirations. With JobJoy, it's not just about employment, it's about fulfillment."
# "Revitalize Workforce: Unleashing Human Potential"
#
# At Revitalize Workforce, we believe in the transformative power of employment. We're not just a staffing agency; we're a dynamic ecosystem where careers flourish and businesses thrive. We handpick talent, equip them with industry-leading skills, and connect them with opportunities that align with their ambitions. For businesses, we offer tailored workforce solutions, ensuring the right people are in the right roles, driving growth and innovation. Together, we're redefining the world of work, one connection at a time.
# "JobJoy Sparks: Igniting Career Bliss! We're not just a staffing agency, we're a dream-matching, talent-nurturing, career-launching powerhouse. Our mission? To spark unparalleled job fulfillment by connecting skilled professionals with opportunities that align with their passions, values, and goals. With JobJoy Sparks, it's never just a job—it's igniting your career bliss!"
# Automotive Repair and Maintenance
# "Revvolutionizing Rides: Your Ultimate Automotive Pit Stop! At Revvolutions, we don't just fix cars, we rejuvenate them! Our seasoned auto- whisperers combine cutting-edge technology with good old-fashioned know-how to breathe new life into your beloved vehicle. From oil changes that feel like a day at the spa to engine overhauls that defy the hands of time, we're not just your mechanics, we're your partners in automotive preservation. With Revvolutions, every ride is a joyride waiting to happen!"
# "Revvolutionizing Rides: Your premier pitstop for automotive rejuvenation! We're not just grease monkeys, we're gearhead gurus, breathing life back into your beloved vehicle with our precision diagnostics, masterful mechanics, and eco-friendly enhancements. At Revvolutionizing Rides, we don't just fix cars, we reimagine them!"
# "Revvolutions: Gear Up for a First-Class Ride! We're not just your average auto repair shop, we're a pit crew of passionately skilled technicians, fine-tuning your vehicle's performance to race-worthy standards. Our eco-friendly garage is a sanctuary for all makes and models, where state-of-the-art diagnostics meet good old-fashioned customer service. Trust us to keep your engine purring and your adventures rolling!"
# Transit and Ground Passenger Transportation
# "JourneyPlus: Your Ticket to Unforgettable Destinations! We're not just a transport company, we're your personal travel curators. At JourneyPlus, we redefine transit with style, safety, and sustainability. Our fleet of eco-friendly vehicles, equipped with the latest technology, ensures a smooth and comfortable ride to your destination. Our team of knowledgeable and friendly drivers are tour guides in their own right, sharing local insights and insider tips to make your journey truly unforgettable. Choose JourneyPlus, where every ride is a journey, and every journey is an experience."
# "JourneyPlus: Your Gateway to Seamless Travel! We are not just a transportation company, we are your personal travel curators. At JourneyPlus, we redefine transit by offering safe, comfortable, and punctual ground passenger services, tailored to your lifestyle. Whether you're a busy professional, a tourist exploring new horizons, or a family on the go, our innovative solutions, from luxury sedans to spacious shuttles, ensure every journey is a Plus!"
# "JourneyPlus: Your Personalized Gateway to the World! We're not just a transportation company, we're an experience-maker. Our innovative ground passenger services seamlessly connect you to airports, cities, and events, ensuring a hassle-free journey. With our eco-friendly fleet, friendly drivers, and top-notch amenities, we redefine transit as more than just a ride - it's the most enjoyable part of your trip!"
# Heavy and Civil Engineering Construction
# "Mighty Foundations: Pioneers in heavy civil engineering, we build the infrastructure that moves the world. From towering bridges to mammoth dams, we harness the power of engineering to tame nature and shape human progress. Our monolithic creations stand the test of time, defying the elements and leaving a legacy of strength and resilience for generations to come. Trust us to transform blueprints into behemoths, and vision into victory."
# "Mighty Foundations: Pioneers in Heavy Civil Engineering, Building Your Vision from the Ground Up. With our unyielding dedication to innovation, safety, and sustainability, we transform landscapes, constructing enduring legacies that stand the test of time. Our team of seasoned engineers and construction experts bring your most ambitious infrastructure projects to life, leaving a trail of masterpieces that empower communities and fuel economic growth."
# "At Titan Constructors, we don't just build structures, we engineer the foundations of progress. Specializing in heavy and civil engineering, our team of seasoned professionals harness the raw power of earthmoving equipment and innovative design to transform landscapes, construct highways, and elevate infrastructure. With us, every project is a testament to human resilience, ambition, and the relentless pursuit of a better tomorrow."
# Other Waste Management Services
# "Revitalize Recycling: Transforming Trash into Treasure"
#
# At Revitalize Recycling, we don't just see waste - we see potential. We're not just another waste management company; we're a team of innovative thinkers and environmental stewards, dedicated to turning trash into treasure. Our cutting-edge technologies and sustainable practices extract the maximum value from waste, diverting it from landfills and giving it new life. From composting organic materials to repurposing industrial byproducts, we're revitalizing the way the world thinks about waste. Join us in our mission to create a cleaner, greener future, one piece of trash at a time.
# "Eco-Spark: Igniting a Greener Tomorrow! We're not your typical waste management company. We're revolutionizing the way you view trash through our innovative, eco-friendly solutions. From biofuels to recycling, we transform waste into valuable resources, empowering businesses and communities to join the sustainability movement. With Eco-Spark, every piece of waste is a stepping stone towards a cleaner, greener future!"
# "Eco-Spark: Igniting a Greener Tomorrow! We're not your average waste managers; we're innovative solutionists, transforming trash into treasure. Our mission is to spark a revolution in the way you view waste, turning it into renewable energy, recyclable resources, and fertile ground for sustainable growth. With us, every bit of waste tells a story of creativity, resilience, and environmental stewardship. Let's light up the future together with Eco-Spark!"
# Data Processing, Hosting, and Related Services
# "Data Nirvana: Your Ultimate Sanctuary for Data! We are not just a cloud, we are your data's home away from home. Our state-of-the-art data processing and hosting services provide a secure, efficient, and scalable solution for all your data needs. With us, your data doesn't just survive, it thrives! Experience the peace of mind that comes with knowing your data is in good hands. Data Nirvana - where data meets its destiny."
# "Data-Elevation: Soaring Heights for Your Business! We are not just a cloud, we are your data's ultimate sanctuary. Our state-of-the-art data processing and hosting services provide robust security, lightning-fast speeds, and unparalleled reliability. With us, your data doesn't just survive, it thrives! Let us catapult your business to soaring heights with our data services that are out of this world."
# "DataSphere Solutions: Transforming Data into Stellar Outcomes
#
# At DataSphere Solutions, we don't just process data – we elevate it to new heights. Our state-of-the-art hosting services provide a safe and secure home for your business's most valuable asset. We go beyond basic data processing, using advanced analytics and AI to uncover hidden insights, enabling your business to make data-driven decisions that propel you towards the stars. With DataSphere Solutions, your data is not just processed, it's transformed into stellar outcomes."
# Automotive Equipment Rental and Leasing
# "VroomVault: Gear up for the future of mobility! We're your one-stop-shop for innovative automotive solutions, offering a wide array of top-notch rental and leasing options to fit every need. From electric dream cars to rugged construction workhorses, our fleet is equipped with the latest technology to keep you ahead of the curve. With exceptional customer service, flexible plans, and a commitment to sustainable transportation, we're not just in the business of renting vehicles—we're in the business of empowering your journey. Experience the freedom to drive your success with VroomVault!"
# "VroomVentures: Gearing Up Your Business! We're not just your average automotive equipment rental and leasing company. We're your strategic partner in mobility, empowering businesses to stay ahead of the curve with our cutting-edge fleet of vehicles and equipment. From bulldozers to busses, we've got you covered. With us, it's not just about getting from point A to B, it's about getting there efficiently, sustainably, and in style. Let's shift gears towards success, together!"
# "VroomVault: Gear up for seamless mobility! We're your one-stop shop for top-tier automotive equipment rentals and leasing, empowering businesses and enthusiasts with innovation on wheels. Experience the perfect blend of power, performance, and precision, as we revitalize your journey towards unmatched driving experiences."
# Advertising Agencies
# "Spark Buzz Advertising: Igniting Brands with Creative Fervor! Our agency is a powerhouse of innovative ideas, whipping up captivating campaigns that sizzle with originality. We don't just sell products, we tell stories that resonate, using cutting-edge strategies to set your brand ablaze in the market. With us, it's not business as usual, it's a creative revolution!"
# "Spark Bright Ideas: Igniting Brands with Creative Fuel! We are a dynamic advertising agency, turning ordinary campaigns into extraordinary experiences. With a blend of innovative strategies, captivating storytelling, and cutting-edge design, we set your brand ablaze in the hearts and minds of your audience. Let us spark your growth and brighten your future!"
# "Spark Buzz Advertising: Igniting Brands, Fueling Growth! We're not just advertisers, we're your creative collaborators, strategically sparking ideas that buzz in the minds of your customers. With a blend of innovative storytelling, data-driven insights, and a dash of quirkiness, we help businesses stand out, connect, and thrive in an attention-deficit world."
# Nonmetallic Mineral Product Manufacturing
# "Stone Solutions Unlimited: Transforming the Earth's Treasures into Infinite Possibilities. We artfully carve beauty from the raw, nonmetallic minerals of our planet, crafting an array of essential products that build, protect, and enhance your world. Our sustainable practices and innovative designs make us the trusted partner in construction, infrastructure, and home improvement."
# "Stone's Throw: Transforming the Earth into Architectural Artistry"
#
# At Stone's Throw, we believe in turning the raw beauty of the earth into extraordinary architectural masterpieces. As a leading player in the Nonmetallic Mineral Product Manufacturing industry, we specialize in the creation and supply of top-tier construction materials, including concrete, cement, lime, and various other mineral-based products.
#
# Our passion lies in sourcing the finest raw materials and subjecting them to our cutting-edge manufacturing processes, ensuring that our offerings not only meet but exceed industry standards. With a keen focus on sustainability and innovation, Stone's Throw is not just a company—we are a creative force that shapes the world one brick at a time.
#
# Join us in our journey as we continue to redefine the boundaries of architectural design, one Stone's Throw at a time.
# "Stone's Throw: Transforming the Earth into Architectural Artistry"
#
# At Stone's Throw, we believe in turning the raw beauty of the earth into refined, functional works of art. Specializing in nonmetallic mineral product manufacturing, we craft everything from custom terrazzo flooring to ornate concrete sculptures. Our team of skilled artisans and engineers share a passion for innovation and sustainability, ensuring that each project not only meets but exceeds our clients' expectations while treading lightly on the planet. With Stone's Throw, you're never far from a masterpiece.
# Scientific Research and Development Services
# "Sparking Innovation: Ignite Innovations is a dynamic powerhouse in the Scientific Research and Development Services industry. We transform the ordinary into the extraordinary, harnessing the power of science to create cutting-edge solutions that propel humanity forward. Our team of visionary scientists and engineers are the torchbearers of discovery, illuminating new paths in technology, healthcare, and environmental sustainability. At Ignite Innovations, we don't just push boundaries—we obliterate them, one groundbreaking discovery at a time."
# "Spark Innovations: Igniting the Future with Fiery Science! We are a dynamic team of inquisitive minds, dedicated to turning the mysteries of the universe into practical solutions. Through rigorous experimentation, data-driven insights, and a dash of disruptive thinking, we help businesses leap into the future, one scientific breakthrough at a time."
# "Sparking Innovation: At Eureka's Edge, we harness the power of inquisitive minds and cutting-edge technology to transform scientific mysteries into life-changing solutions. Our dynamic research and development services ignite imagination, foster collaboration, and propel industries into the future."
# Full-Service Restaurants
# Welcome to Culinary Symphony, where every meal is a masterpiece and your taste buds are the audience! We are a full-service restaurant that orchestrates an unforgettable dining experience, combining delectable dishes, exquisite ambiance, and exceptional service. Our menu, a symphony of flavors, is carefully curated by our renowned chef, using only the freshest ingredients to create culinary harmonies that dance on your palate. From the moment you step into our restaurant, you're not just a guest, but a valued maestro, conducting your own gastronomic journey. So, come, raise your fork, and let the symphony begin!
# "At Savorful Symphony, we orchestrate a dining experience that is a feast for the senses. Our full-service restaurant is a harmonious blend of exquisite cuisine, enchanting ambiance, and exceptional service, all coming together to create a masterpiece of memory-making moments. From the moment you step into our establishment, you're not just a customer, but a cherished guest, as we conduct a symphony of flavors to tantalize your taste buds and leave you with a longing for more. So, come, let us serenade your senses and conduct a culinary concert that will resonate in your heart long after the meal is over."
# "Mouthwatery Magic: A Culinary Journey through Taste and Culture"
#
# Immerse yourself in the world of exquisite flavors and cultural diversity at Mouthwatery Magic, your one-stop destination for an unparalleled full-service dining experience. Our ever-evolving menu, crafted by our dedicated team of culinary mavericks, takes you on a gastronomic adventure that celebrates the finest ingredients from around the globe. From the moment you step into our warm and inviting atmosphere, our attentive staff caters to your every whim, ensuring a truly personalized dining experience. At Mouthwatery Magic, we believe that sharing a meal is a celebration of life, and we strive to create unforgettable memories with every dish served. Join us at the table and let the magic unfold.
# Business Schools and Computer and Management Training
# "TechLearn Academy: Igniting Bright Minds, Bridging Business and Technology!"
#
# TechLearn Academy is a revolutionary Business School dedicated to cultivating innovative leaders who excel at the intersection of business and technology. We provide dynamic, hands-on computer and management training programs that empower students to transform organizations and drive growth in the digital age. Our expert faculty and state-of-the-art facilities foster a vibrant, collaborative learning environment where creativity, critical thinking, and strategic problem-solving skills flourish. Together, we're shaping the future of business education, one trailblazing professional at a time!
# "TechMind Academy: Igniting Sparks of Innovation! We are a dynamic Business School, bridging the gap between technology and management. Our mission is to cultivate future leaders who are well-versed in both cutting-edge computer science and strategic management. Through immersive, hands-on training programs, we empower professionals to drive digital transformation, lead diverse teams, and create sustainable business solutions. Join us in our quest to shape a world where technology and management coexist in perfect harmony, fueling endless possibilities for growth and success!"
# "TechMind Academy: Igniting Sparks of Innovation! We are a dynamic Business School, bridging the gap between cutting-edge technology and strategic management. Our immersive Computer and Management Training programs empower professionals to become visionary leaders, driving digital transformation and sustainable growth in the modern business landscape."
# Architectural, Engineering, and Related Services
# "BrightBrain Builders: Fusing Art & Science"
#
# At BrightBrain Builders, we don't just construct buildings; we craft experiences. We're a team of architects, engineers, and creative visionaries who believe in the transformative power of space. Our mission is to blend artistic design with scientific precision, creating structures that inspire, innovate, and resonate with the world around them. Whether it's an office tower touching the sky or a community center nestled in the heart of a neighborhood, every project is a chance for us to challenge conventions, push boundaries, and redefine what's possible. With us, you're not just getting a service, you're investing in a partnership where dreams meet reality, and ideas become landmarks.
# "Visionary Structures: Where Innovation Meets Inspiration"
#
# At Visionary Structures, we go beyond the blueprints to craft extraordinary spaces that blend artistic vision with scientific precision. Our team of architects and engineers collaborate to transform your dreams into sustainable, functional, and breathtaking structures that stand the test of time. We don't just build; we create experiences that inspire and empower. With us, you'll embark on a journey where creativity meets engineering, resulting in awe-inspiring architectural marvels that leave a lasting impact on communities and the environment.
# "At Blueprint Bound, we seamlessly weave art and science into spaces, crafting innovative solutions that inspire and endure. Our team of visionary architects and engineers transforms dreams into dynamic structures, shaping the future with every brick and beam. Together, we reimagine possibilities and build sustainable legacies."
# Landscaping Services
# "Verdant Visions: Transforming Spaces into Lush Oases! Our team of green-thumb alchemists wields the power of nature to craft breathtaking landscapes that inspire, rejuvenate, and elevate your outdoor living experience. From elegant garden designs and enchanting hardscapes to eco-friendly maintenance solutions, we nurture your property's unique beauty, ensuring it flourishes in harmony with the environment. With Verdant Visions, your landscape is not just a space; it's a living, breathing work of art."
# "VistaScapes: Crafting Edens from Earthly Chaos! We transform your outdoors into a personal paradise, where nature's beauty meets design brilliance. Our green-thumb artisans sculpt living landscapes that dance with color, whisper with tranquility, and stand the test of time. With VistaScapes, your world blooms brighter."
# "GreenSprouts: Cultivating Outdoor Oases! We are a team of green-thumbed artisans, transforming ordinary yards into extraordinary sanctuaries. Our eco-conscious designs, meticulous maintenance, and innovative solutions will nurture your nature-connected lifestyle, making your landscape a true reflection of you. Let's grow your dreams into a vibrant reality!"
# Automobile Dealers
# "Spinning Wheels Autos: Revving Up Dreams, One Drive at a Time! We're not just dealers, we're dream weavers, crafting mobility solutions that fit your lifestyle. Our curated collection of vehicles, from classic cruisers to cutting-edge electrics, is matched only by our commitment to exceptional customer service. At Spinning Wheels Autos, every journey begins with a smile and ends with a story. Come, test drive your dreams today!"
# "At 'Rev it Up Reams,' we don't just sell cars, we fuel dreams! Our state-of-the-art showroom is a vibrant playground for automobile aficionados, where every gleaming vehicle tells a story of power, style, and innovation. We're not just dealers; we're curators of an extraordinary driving experience. With unparalleled customer service, meticulously maintained pre-owned vehicles, and a finger on the pulse of the latest automotive trends, we ensure that every visit to Rev it Up Reams is a thrilling ride down the fast lane of life!"
# " ignite your drive! At 'Zippy Motors', we redefine the art of automobile dealerships, fueling your passion for premium rides with our unparalleled range of top-notch vehicles. Our seasoned experts, armed with market insights and product knowledge, ensure a matchless buying experience that caters to your unique needs. At Zippy Motors, we don't just sell cars; we craft memories in motion. Get ready to embark on an exhilarating journey as you zoom into the future with us! "
# Transportation and Warehousing
# "Jetstream Junction: Your Cargo's Expeditious Crossroads! We seamlessly blend cutting-edge technology with tried-and-true logistics, orchestrating a symphony of transportation and warehousing that dances your goods to their destinations with lightning speed and bulletproof security. Our commitment? To transform the humdrum world of cargo into an exhilarating ride of efficiency, reliability, and sustainability."
# "Jetstream Junction: Your cargo's concierge in the cloud! We seamlessly blend cutting-edge technology with good old-fashioned customer service to create a transport and warehousing experience that's out of this world. From drone-driven delivery networks to smart storage solutions, we ensure your goods jetstream through logistical labyrinths with lightning speed and precision."
# "Jetstream Junction: Your Cargo's Home Away from Home! We seamlessly connect the world's dots by providing smart, secure, and sustainable transportation and warehousing solutions. Our innovative logistics orchestration, powered by a dedicated team of supply chain virtuosos, ensures your goods dance their way to their destination, on time and in perfect rhythm. With Jetstream Junction, it's not just about moving goods; it's about creating a harmonious journey for every cargo, every time."
# Furniture and Home Furnishings Stores
# "At Nestled Comforts, we believe that your home is a reflection of your personality and spirit. That's why we offer a wide array of furniture and home furnishings that are not just stylish and trendy, but also tell a story. Our products are carefully curated to bring warmth, character, and a touch of enchantment to your living spaces. From cozy couches to elegant dining sets, from vibrant area rugs to exquisite wall art, we have everything you need to create a sanctuary that is as unique as you are. At Nestled Comforts, we don't just sell furniture - we help you craft experiences and memories that will last a lifetime."
# "At Nestled Comforts, we believe that a house becomes a home through the art of thoughtful design and cherished memories. As a premier furniture and home furnishings destination, we curate an exquisite collection of pieces that not only elevate your living space but also tell your unique story. From plush sofas that welcome endless conversations to handcrafted dining tables that gather loved ones, each item is carefully selected to inspire warmth, harmony, and joy. Our dedicated team of design enthusiasts is committed to providing you with personalized service, expert advice, and creative solutions, transforming your house into a deeply nestled comfort - a true reflection of you."
# "Revive Interiors: Transforming Havens, where we breathe life into your living spaces. We curate an exquisite blend of contemporary and classic furniture, handpicked from global artisans, to bring you a world of style and comfort. Our eco-friendly materials, personalized designs, and seamless delivery make us the trusted choice for your home transformation. Experience the joy of living in a Revive Interiors home, where every piece tells a story and echoes your personality."
# Sporting and Athletic Goods Manufacturing
# "Vortex Athletics: Pioneering the Future of Fitness! We're not just manufacturing sports gear, we're crafting triumphs, one athlete at a time. Our innovative designs, top-tier materials, and relentless pursuit of excellence make us the go-to choice for those who refuse to settle for ordinary. From the schoolyard to the Olympic arena, we fuel ambition, empower determination, and celebrate every victory. With Vortex Athletics, it's more than a game - it's a lifestyle."
# "Fit-Stride: Unleashing the Champion Within! We're not just about crafting athletic goods, we're about fueling the fire in every athlete. Our innovative designs, cutting-edge technology, and relentless pursuit of excellence empower athletes to break boundaries and set new records. From the track to the court, the field to the gym, Fit-Stride is your trusted partner in achieving sporting greatness."
# "Fit-Leap Enterprises: Igniting the Spirit of Competition and Fitness! We are a dynamic powerhouse in the Sporting and Athletic Goods Manufacturing industry, crafting high-performance gear for athletes who dare to defy boundaries. Our innovative designs, premium materials, and cutting-edge technology empower champions to unleash their true potential, making Fit-Leap the trusted partner for those who crave the thrill of victory and the joy of a healthy lifestyle."
# Janitorial Services
# "Spickety-Span: Your Sanctuary of Shine! We transform the mundane into magic, turning dirty doldrums into dazzling displays. Our eco-friendly solutions and dedicated 'Sanitation Superheroes' ensure your spaces are not just clean, but crisp and vibrant. With us, it's not just about swishing mops and dustpan collections; it's about crafting a healthier, happier environment where every corner sparks joy. Let Spickety-Span redefine your cleaning experience!"
# "Spickety-Split: Your Partner in Pristine! We're not just about clean; we're about sparkle. Our expert team of janitorial professionals brings a dash of magic to your spaces, turning grunge into gleam in a splitt second. With us, it's not just about getting the job done - it's about creating an environment that's as refreshing as a crisp, spring morning. So why wait? Let Spickety-Split transform your world today!"
# "Spickety-Span spotless solutions: Transforming everyday grime into gleaming spaces, our dedicated team of janitorial experts breathe life back into your business environment, one squeaky-clean surface at a time. Because a immaculate workspace is not just a reflection of professionalism, it's an investment in health, happiness, and harmony."
# Vocational Schools
# "Spark Skills: Igniting Passions, Forging Futures! Our vocational schools are a vibrant crucible of hands-on learning, where we transform curious minds into skilled professionals. From culinary arts to robotics, we offer a diverse range of programs, tailored to equip students with the right blend of theoretical knowledge and practical expertise. At Spark Skills, we don't just teach trades, we build dreams, one skill at a time."
# "Ignite Education: Fueling Future Trailblazers! Ignite Education is a vocational school powerhouse, illuminating the path to prosperous careers in the trades. Our hands-on, innovative programs spark curiosity, foster real-world skills, and cultivate a diverse community of passionate professionals. Together, we're fueling the workforce, one trailblazer at a time!"
# "Ignite Education: Fueling Future Trailblazers! Ignite Education is a leading vocational school, dedicated to empowering learners of all ages to chart their own career path. We believe in hands-on, industry-relevant training, fostering creativity, critical thinking, and collaboration. From culinary arts to coding, automotive repair to allied health, our students ignite their passions, forge new skills, and fuel their future success!"
# Internet Publishing and Broadcasting and Web Search Portals
# "Surfing the Net has never been more thrilling! At WaveCrest Digital, we're not just riding the waves of the Internet - we're creating them. As a leading innovator in the Internet Publishing and Broadcasting industry, we provide dynamic web search portals that connect users with the world's most captivating content. From cutting-edge news to viral videos, we curate the web's finest offerings and serve them up with a side of sophisticated search technology. Join us as we dive into the digital ocean and discover the treasures within."
# "Surfing the Net Network, where your digital voyage becomes a seamless journey! We are a dynamic Internet Publishing and Broadcasting company, specializing in Web Search Portals that connect users to a world of knowledge and entertainment with just a click. Our innovative search algorithms, personalized content curation, and user-friendly interface make us the go-to platform for millions of web surfers worldwide. Join us in our quest to revolutionize the way people explore the digital landscape!"
# "Surfing the Net has never been more thrilling! Our innovative digital platform, NetSplash, is a one-stop-shop for all your web needs. From up-to-the-minute news and engaging blogs to comprehensive search capabilities and personalized content recommendations, NetSplash empowers users to dive deeper into the vast ocean of the internet. Join us as we revolutionize the way you explore, discover, and connect online."
# Social Assistance
# ...
# "Vitality on the Go: Your Partner in Mobile Medicine! We're not just a healthcare provider, we're a health movement. Our state-of-the-art mobile medical units bring top-tier medical services to your doorstep, making healthcare convenient, accessible, and personal. From routine check-ups to specialized treatments, we're committed to keeping you in the pink of health, wherever you are."
# Construction
# "Brick & Beam Builders: Crafting Solid Foundations for Your Future! Our team of skilled artisans and engineers transform visions into vertical masterpieces, blending traditional craftsmanship with innovative design. From initial blueprint to final brick, we construct more than buildings; we create homes, businesses, and legacies that stand the test of time."
# "Brick & Beam Innovations: Where creative vision meets structural mastery. We're not just building houses, we're crafting homes with heart and head, combining cutting-edge design concepts and robust construction techniques to elevate your living space. Our seasoned team of architects, engineers, and craftsmen share a passion for delivering quality that stands the test of time."
# "BrickCraft: Building Imagination into Reality"
#
# At BrickCraft, we don't just construct buildings; we craft dreams into reality. Our team of skilled artisans and engineers collaborate to create innovative, sustainable, and awe-inspiring structures that blend form and function seamlessly. We believe in constructing more than walls and roofs; we build communities, inspire creativity, and shape the future with our hands and hearts. With BrickCraft, your vision is our blueprint, and together, we'll create a legacy that stands the test of time.
# Waste Collection
# "Revamping Waste, Inc.: Transforming Trash Troubles into Triumphs! We're not just your average waste collectors; we're your eco-warriors, innovation pioneers, and sustainability champions. We turn every garbage bag into a treasure trove of resources, every landfill into a potential energy source. With us, waste becomes a thing of the past, making way for a cleaner, greener future. Join us in our mission to redefine waste and reimagine sustainability!"
# "Revital- debris: Transforming Trash to Treasure! We're not just your average waste collectors, we're your eco-partners on a mission to convert discarded materials into valuable resources. Our innovative sorting technology and creative repurposing initiatives ensure that less ends up in landfills and more in the hands of those who can give it new life. With Revital-debris, waste nothing and gain everything!"
# "Revitalize Recycling: Transforming Trash Troubles into Triumphs! We're not just about collecting waste; we're on a mission to redefine sustainability. At Revitalize Recycling, we turn your trash into treasure by harnessing the power of innovative technology and eco-friendly practices. Together, let's build a cleaner, greener future, one waste bin at a time!"
# Repair and Maintenance
# "Revitalyze Rebuilders: Resurrecting Reliability, Restoring Rhythm! We're not just in the repair and maintenance business, we're in the 'renewed peace of mind' business. Our team of skilled artisans breathe life back into your ailing equipment, ensuring they dance to your rhythm once more. With us, it's not just about fixing - it's about forging relationships, fostering trust, and fostering functionality."
# "Revitalyze Rebuilders: Resurrecting Reliability, Restoring Rhythm! We're not just about fixing what's broken; we breathe life back into your essentials, ensuring smooth operations and prolonging the party. Our seasoned artisans masterfully mend, maintain, and modernize, turning lemons into lemonade machines. With Revitalyze, it's not just repairs, it's renewal!"
# "Revitalyze Restoration: Reviving Spaces, Rejuvenating Lives. We're not just in the business of fixing broken fixtures or maintaining machinery; we breathe new life into your living spaces and work environments. Our team of skilled technicians, armed with a perfect blend of craftsmanship and cutting-edge technology, are committed to providing top-notch repair and maintenance services that exceed expectations. With Revitalyze, it's not just about getting the job done - it's about making your world a more comfortable, safer place to live and work in."
# Electric Power Generation, Transmission and Distribution
# "SparkFlow: Igniting the Grid! We're not just electrifying homes and businesses, we're energizing communities and shaping the future. Harnessing the power of innovative technologies, we generate, transmit, and distribute green energy, ensuring a sustainable and bright tomorrow. At SparkFlow, we don't just deliver power, we deliver progress!"
# "SparkFlow: Igniting the Future of Energy! We're not just wires and transformers, we're the dynamic bridge between raw power and your everyday needs. Harnessing the pulse of electric power generation, we transmit and distribute energy with an unwavering commitment to sustainability, innovation, and community impact. Experience the flow of clean, reliable, and intelligent energy solutions with SparkFlow."
# "SparkGen: Igniting the Future with Reliable and Sustainable Energy! We are the architects of the new energy landscape, specializing in the generation, transmission, and distribution of electric power. Our mission is to provide innovative, efficient, and eco-friendly energy solutions that empower communities and businesses, driving growth and sustainability. At SparkGen, we're not just delivering power; we're delivering a brighter, cleaner, and more connected world."
# Drinking Places (Alcoholic Beverages)
# "Welcome to 'BrewsCheer' - your friendly neighborhood watering hole, where every hour is happy hour! Quench your thirst with our handcrafted artisanal brews, or savor the rich heritage in our global wine and spirit collections. Our cozy, rustic ambience, coupled with live music and engaging events, makes BrewsCheer the perfect spot for unwinding, socializing, and cheering to life's simple pleasures. Come indulge in a unique sensory adventure that will leave you craving for more!"
# "Vintages and Vibrations: A Craft Brewery Bistro"
#
# Step into a world where the love for handcrafted brews meets the art of fine dining. At Vintages and Vibrations, we celebrate the symphony of flavors in every sip and bite. Our microbrewery creates an ever-changing tap list of innovative, small-batch brews that pair perfectly with our seasonal, locally-sourced menu. With live music performances setting the tone, we invite you to unwind, savor the taste of excellence, and immerse yourself in the lively rhythm of good times. Vintages and Vibrations - where imbibing meets intimacy, and every visit is an experience.
# "Welcome to 'Liquid Legends' - your mythical sanctuary for handcrafted elixirs and artisanal brews! Our enchanting tavern transports you to a world where every sip tells a story. From our mystical cocktails, crafted with potions as ancient as the legends themselves, to our divine draft beers forged by the gods of brewing, we promise an otherworldly experience that will leave you spellbound. Come, quench your thirst and lose yourself in the lore at Liquid Legends!"
# Arts, Entertainment, and Recreation
# "Welcome to Colorful Rhythms, where we transform moments into masterpieces! We are a boutique entertainment agency specializing in immersive arts experiences. Our passionate team of performers, artists, and designers create unique events that ignite the senses and inspire the soul. From enchanting live music performances to interactive art installations, our mission is to bring joy, creativity, and connection to communities through the magic of arts and entertainment. Let us paint your next occasion with the vibrant hues of unforgettable memories!"
# "Welcome to Colorful Rhythms, where we transform moments into masterpieces! Our creative agency specializes in curating immersive experiences that ignite the senses and inspire the soul. From vibrant street art tours and captivating dance performances, to enchanting musical events and interactive workshops, we celebrate the Art of Life. Join us as we paint the town with joy, one brushstroke at a time!"
# "Catalyst Carnival Creations: Igniting Imagination through Interactive Art Experiences. We are a mobile art studio, specializing in transforming ordinary events into extraordinary adventures. Our team of talented artists and performers engage, entertain, and inspire audiences of all ages, through immersive workshops, captivating live performances, and fantastical installations. Let us curate your next celebration into a colorful journey of creativity and connection."
# Environmental Consulting Services
# "Eco-Visionaries: Transforming the Future through Sustainable Solutions! We are a dynamic team of environmental experts, dedicated to helping businesses thrive while preserving our planet. Our innovative strategies empower organizations to reduce their carbon footprint, optimize resource efficiency, and navigate complex environmental regulations with ease. Together, let's create a greener, cleaner, and more prosperous world for all!"
# "Eco-Visionaries: Transforming the Future through Sustainable Solutions! We are a dynamic team of environmental consultants, dedicated to helping businesses thrive while minimizing their ecological footprint. By integrating innovative strategies, scientific expertise, and cutting-edge technology, we craft customized roadmaps to navigate the complexities of environmental regulations and sustainability challenges. Together, we forge a greener, cleaner, and more prosperous world for generations to come."
# "Eco-Visionaries: Transforming the Future through Sustainable Solutions! We are a dynamic team of environmental experts, dedicated to helping businesses thrive while preserving our planet. Our innovative strategies breathe life into sustainability initiatives, turning regulatory compliance into competitive advantage. Together, we can shape a greener, cleaner, and prosperous world for all!"
# Pet Care (except Veterinary) Services
# "Pawsitively Fabulous Pet Services: Where Tail-Wagging Tales Begin! We're not just walking dogs or cleaning litter boxes; we're creating unforgettable experiences for your furry family members. Our holistic approach to pet care ensures that every four-legged friend in our program receives VIP treatment, complete with belly rubs, playtime, and delicious organic treats. We believe in building strong bonds, providing personalized care, and going the extra mile to ensure your pet's well-being. At Pawsitively Fabulous Pet Services, we don't just cater to pets—we celebrate them!"
# "Pawsitive Purrfections: Where Tails Wag and Smiles Flourish! Our passion is providing premier, personalized experiences for your beloved pets. From tailored playtime and top-notch grooming to luxurious lodging, we offer a range of services to keep your furry friends purring and wagging in pure delight. At Pawsitive Purrfections, your pet's happiness is our top priority, and we treat every furry guest as if they were our very own."
# "Pawsitively Pampered Pet Palace: Where Tail-Wagging Tales Begin! We roll out the red carpet for your furry VIPs (Very Important Pets), providing luxurious lodging, grooming pampering, and adventure playdates. Our passionate pet professionals ensure your pets bask in a safe, fun-filled, and loving environment. Because your pets deserve the best, we provide nothing less. At Pawsitively Pambered Pet Palace, every day is a tail-wagging, bark-filled celebration of life with our beloved pets!"
# Apparel, Piece Goods, and Notions Merchant Wholesalers
# "Stitch & Script is a trendsetting apparel wholesaler, specializing in unique fabrics and notions from around the globe. We're not just suppliers, we're storytellers, weaving together cultural traditions and modern fashion to bring you one-of-a-kind pieces that speak volumes. With us, you're not just buying a product, you're investing in a narrative."
# "Stitching Together Style: At Pinz & Needles, we're not just wholesalers, we're your fashion-forward partner. From the latest textiles to timeless notions, we curate a diverse and high-quality selection of apparel supplies, fostering creativity and innovation in the fashion world. With unparalleled customer service and a finger on the pulse of industry trends, Pinz & Needles is the one-stop shop for designers and retailers seeking to make their mark in the world of style."
# "Stitching Together Style: At 'The Thread Exchange', we're not just wholesalers, we're your fashion-forward partners. We curate a vast selection of apparel, piece goods, and notions, from the latest streetwear trends to timeless classics. With our finger on the pulse of the industry, we provide our clients with the essentials to create clothing that speaks to their unique customers. We're more than just a supplier, we're a one-stop-shop for all your fashion needs, stitching together style, quality, and affordability, for a seamless and successful business."
# Real Estate
# "Propelle Property: Igniting your journey to exceptional real estate! We're not just about buildings, we're about cultivating dream homes and lucrative investments. With Propelle, every brick whispers opportunity, every view radiates potential. Our dynamic team, fueled by passion, market insight, and a touch of ingenuity, empowers clients to leap property ladders and reach real estate goals. With Propelle Property, you're not just buying or selling – you're launching!"
# "Elevated Spaces: Your Personal Real Estate Concierge"
#
# Imagine a real estate experience that feels less like a transaction and more like a personalized journey, tailored to your unique needs and desires. At Elevated Spaces, we don't just sell properties; we create dreams and craft lifestyles. Our team of expert concierges is dedicated to providing you with an unparalleled, white-glove service, ensuring that every step of your property venture is seamless and rewarding. From identifying the perfect home to managing the finest details of your transaction, Elevated Spaces is your partner in transforming four walls into the sanctuary you've always envisioned. Experience the difference with Elevated Spaces, where your dreams are our blueprint.
# "Elevating Horizons: Your Partner in Property Perfection. We don't just sell homes, we craft personalized living experiences. Our seasoned real estate maestros harmonize your dreams with the perfect property, orchestrating seamless transactions with a flourish. Whether you're buying, selling, or investing, let us compose your real estate symphony today."
# Textile Mills
# "Stitching Dreams into Reality, ThreadTales is a Textile Mills powerhouse, weaving innovation with tradition. Our looms echo the pulse of creativity, crafting vibrant stories in fabric for fashion-forward brands and eco-conscious consumers alike. We're not just spinning yarns, we're spinning connections that drape the world in sustainability, style, and soul."
# "Stitching Dreams into Reality, Fabrication Foundry is a Textile Mills powerhouse, weaving innovation with tradition. Our looms resonate with the heartbeat of creativity, transforming raw threads into exquisite fabrics that drape the world in elegance and comfort. We are not just a Textile Mill, we are the silent storytellers, crafting tales of style and sustainability in every yard we produce."
# "Stitching Dreams into Reality, Fabricatex is a vibrant textile mill where imagination and innovation interweave to create an enchanting tapestry of colors, patterns and textures. Our state-of-the-art looms and passionate artisans transform raw threads into exquisite fabrics, tailoring dreams into tangible reality. We invite you to explore the world of Fabricatex, where creativity meets craftsmanship, and every thread tells a story."

# %%
# clean up to better meet definition of "short business description"

filtered_descriptions = [
    desc.replace("\\'", "'").replace("\n", " ") for desc in all_descriptions if len(desc.replace("\\'", "'").replace("\n", " ")) < 500
]

# %%
# Save validation dataset to file

json_file_path = 'eval_data.json'
with open(json_file_path, 'w') as file:
    json.dump(filtered_descriptions, file)
